# %% [markdown]
# I need to count all the frequencies of all the triplets in each of the video sequence.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np


results_cholecT50_chal = [np.nan, np.nan, np.nan, np.nan, 1.42380420e-01, 5.12557663e-04, np.nan, 3.32626728e-01,
          1.94041245e-02, 4.41499286e-03, 1.51810978e-02, 1.05866348e-01, 7.66676512e-01, 
          3.34643930e-01, np.nan, np.nan, np.nan, 3.49844877e-01, 2.36705437e-01, 6.40751279e-01,
          np.nan, np.nan, 6.16255123e-01, 3.82526038e-01, np.nan, np.nan, np.nan, np.nan, np.nan, 
          9.38378809e-01, np.nan, 6.81760326e-01, np.nan, 2.39063315e-01, 6.76337083e-01, np.nan, 
          1.46892996e-01, np.nan, np.nan, np.nan, 2.24427652e-02, np.nan, np.nan, np.nan, np.nan, 
          np.nan, 5.29207639e-03, np.nan, 6.28930818e-03, np.nan, np.nan, np.nan, 8.23852417e-04, 
          np.nan, 4.13746771e-03, 5.78127295e-02, np.nan, 9.06361298e-02, 5.12866891e-01, np.nan, 
          7.72888383e-01, np.nan, 5.74473847e-02, 1.00791122e-03, np.nan, np.nan, np.nan, np.nan, 
          5.51408207e-01, 7.13270129e-01, np.nan, np.nan, 2.06043956e-01, np.nan, np.nan, np.nan, 
          np.nan, 1.03012725e-01, 7.70445042e-01, 6.79152307e-01, np.nan, np.nan, 7.19090642e-02, 
          np.nan, np.nan, np.nan, np.nan, np.nan, 4.20168067e-03, np.nan, 1.05711606e-02, np.nan, 
          np.nan, np.nan]

# Count NaNs
nan_count = np.sum(np.isnan(results_cholecT50_chal))
print("Number of NaNs:", nan_count)
print(np.nanmean(results_cholecT50_chal))
# Out:
# Number of NaNs: 55
# 0.2890225939592308

# %%
nan_indices = np.where(np.isnan(results_cholecT50_chal))[0]  # [0] extracts the indices from the tuple

print("Indices of NaNs:", nan_indices)
# Out:
# Indices of NaNs: [ 0  1  2  3  6 14 15 16 20 21 24 25 26 27 28 30 32 35 37 38 39 41 42 43
#  44 45 47 49 50 51 53 56 59 61 64 65 66 67 70 71 73 74 75 76 80 81 83 84
#  85 86 87 89 91 92 93]

# %%
from utils.dataset_variables import TripletSegmentationVariables
from os.path import join

# %%
import json
from collections import Counter
from typing import List, Dict, Tuple

def count_triplets(video_files,
                   triplet_mapping):
    """
    Counts the frequency of each triplet in a set of CholecT50 videos and identifies missing triplets.
    
    Args:
        video_files (List[str]): List of paths to video JSON annotation files.
        triplet_mapping (Dict[int, str]): Dictionary mapping triplet IDs to triplet names.

    Returns:
        Tuple[Dict[str, int], List[str]]: 
            - Dictionary with triplet names as keys and their counts as values.
            - List of missing triplet names (triplets that do not appear in the dataset).
    """
    triplet_counter = Counter()

    # Iterate through each video annotation file
    for file_path in video_files:
        with open(file_path, "r") as f:
            data = json.load(f)
        
        # Extract annotations from JSON
        annotations = data.get("annotations", {})

        for frame_id, frame_annotations in annotations.items():
            for annotation in frame_annotations:
                triplet_id = annotation[0] # First element in list is the triplet ID
                if triplet_id != -1:
                    triplet_id = str(triplet_id + 1) # move zero to one starting spot. 
                    if triplet_id in triplet_mapping:
                        triplet_name = triplet_mapping[triplet_id]
                        triplet_counter[triplet_name] += 1
                    else: 
                        raise ValueError(f'cant find triplet_id {triplet_id} for frame_id {frame_id} ')   

    # Identify missing triplets
    present_triplets = set(triplet_counter.keys())
    all_triplets = set(triplet_mapping.values())
    missing_triplets = sorted(all_triplets - present_triplets)

    return dict(triplet_counter), missing_triplets

# %%
# Example Usage:

ann_dir = '../data/CholecT50/labels'
test_list =  [92, 96, 103, 110, 111]
test_list_path = [ join(ann_dir, f'VID{test_vid_id}.json')  for test_vid_id in test_list]
triplet_mapping = TripletSegmentationVariables.categories['triplet']

print(test_list_path)

triplet_counts, missing_triplets = count_triplets(test_list_path, triplet_mapping)
 
print("Triplet Counts:", triplet_counts)
print("Missing Triplets:", missing_triplets)
# Out:
# ['../data/CholecT50/labels\\VID92.json', '../data/CholecT50/labels\\VID96.json', '../data/CholecT50/labels\\VID103.json', '../data/CholecT50/labels\\VID110.json', '../data/CholecT50/labels\\VID111.json']
# Triplet Counts: {'grasper,null_verb,null_target': 719, 'grasper,grasp,gallbladder': 2758, 'grasper,retract,gallbladder': 1194, 'hook,null_verb,null_target': 962, 'grasper,grasp,peritoneum': 324, 'hook,dissect,cystic_duct': 884, 'hook,coagulate,blood_vessel': 35, 'hook,dissect,cystic_artery': 240, 'hook,cut,blood_vessel': 13, 'clipper,null_verb,null_target': 37, 'clipper,clip,cystic_duct': 161, 'clipper,clip,cystic_artery': 96, 'scissors,cut,cystic_artery': 44, 'scissors,cut,cystic_duct': 78, 'bipolar,coagulate,blood_vessel': 74, 'bipolar,null_verb,null_target': 57, 'hook,dissect,gallbladder': 2147, 'irrigator,aspirate,fluid': 179, 'grasper,retract,liver': 1218, 'grasper,grasp,specimen_bag': 646, 'grasper,pack,gallbladder': 98, 'bipolar,coagulate,liver': 388, 'irrigator,null_verb,null_target': 67, 'hook,coagulate,liver': 2, 'irrigator,irrigate,liver': 3, 'irrigator,irrigate,abdominal_wall_cavity': 1, 'bipolar,grasp,specimen_bag': 3, 'bipolar,coagulate,abdominal_wall_cavity': 60, 'bipolar,dissect,cystic_artery': 82, 'hook,cut,peritoneum': 92, 'bipolar,dissect,cystic_duct': 37, 'grasper,grasp,liver': 16, 'grasper,grasp,omentum': 6, 'grasper,grasp,gut': 24, 'bipolar,dissect,gallbladder': 5, 'scissors,cut,omentum': 3, 'scissors,null_verb,null_target': 9, 'hook,retract,gallbladder': 4, 'hook,dissect,peritoneum': 54, 'grasper,grasp,cystic_duct': 174, 'clipper,clip,blood_vessel': 14, 'grasper,retract,gut': 13, 'bipolar,coagulate,peritoneum': 12, 'hook,coagulate,cystic_duct': 1, 'grasper,grasp,cystic_pedicle': 1}
# Missing Triplets: ['bipolar,coagulate,cystic_artery', 'bipolar,coagulate,cystic_duct', 'bipolar,coagulate,cystic_pedicle', 'bipolar,coagulate,cystic_plate', 'bipolar,coagulate,gallbladder', 'bipolar,coagulate,omentum', 'bipolar,dissect,adhesion', 'bipolar,dissect,cystic_plate', 'bipolar,dissect,omentum', 'bipolar,grasp,cystic_plate', 'bipolar,grasp,liver', 'bipolar,retract,cystic_duct', 'bipolar,retract,cystic_pedicle', 'bipolar,retract,gallbladder', 'bipolar,retract,liver', 'bipolar,retract,omentum', 'clipper,clip,cystic_pedicle', 'clipper,clip,cystic_plate', 'grasper,dissect,cystic_plate', 'grasper,dissect,gallbladder', 'grasper,dissect,omentum', 'grasper,grasp,cystic_artery', 'grasper,grasp,cystic_plate', 'grasper,retract,cystic_duct', 'grasper,retract,cystic_pedicle', 'grasper,retract,cystic_plate', 'grasper,retract,omentum', 'grasper,retract,peritoneum', 'hook,coagulate,cystic_artery', 'hook,coagulate,cystic_pedicle', 'hook,coagulate,cystic_plate', 'hook,coagulate,gallbladder', 'hook,coagulate,omentum', 'hook,dissect,blood_vessel', 'hook,dissect,cystic_plate', 'hook,dissect,omentum', 'hook,retract,liver', 'irrigator,dissect,cystic_duct', 'irrigator,dissect,cystic_pedicle', 'irrigator,dissect,cystic_plate', 'irrigator,dissect,gallbladder', 'irrigator,dissect,omentum', 'irrigator,irrigate,cystic_pedicle', 'irrigator,retract,gallbladder', 'irrigator,retract,liver', 'irrigator,retract,omentum', 'scissors,coagulate,omentum', 'scissors,cut,adhesion', 'scissors,cut,blood_vessel', 'scissors,cut,cystic_plate', 'scissors,cut,liver', 'scissors,cut,peritoneum', 'scissors,dissect,cystic_plate', 'scissors,dissect,gallbladder', 'scissors,dissect,omentum']

# %% [markdown]
# do the nans matchup to the missing triplets?

# %%
missing_triplet_ids = sorted([int(triplet_id)-1 for triplet_id, name in triplet_mapping.items() if name in missing_triplets])
print(missing_triplet_ids)
print(len(missing_triplet_ids))
print(len(triplet_counts))
# Out:
# [0, 1, 2, 3, 6, 14, 15, 16, 20, 21, 24, 25, 26, 27, 28, 30, 32, 35, 37, 38, 39, 41, 42, 43, 44, 45, 47, 49, 50, 51, 53, 56, 59, 61, 64, 65, 66, 67, 70, 71, 73, 74, 75, 76, 80, 81, 83, 84, 85, 86, 87, 89, 91, 92, 93]
# 55
# 45

# %%
if missing_triplet_ids == nan_indices.tolist():
    print("The lists are exactly the same (including order).")
else:
    print("The lists are different.")
# Out:
# The lists are exactly the same (including order).

# %% [markdown]
# nans represent the missing ground-truth only. In this example. However that means, somethings that should be zeros are Nans
#
# You should only have NaNs when there is no prediction and no ground_truth.
#
#
#
# 1. When there is 0 ground truth and there are some predictions, these should be zero.
# 2. When there is 0 prediction and there exists ground_truth, this should also be zero
#
# lets check these out.

# %% [markdown]
# So all the predictions are being penalized.

# %% [markdown]
# ### 1. When there is 0 ground truth and there are some predictions, these should be zero.

# %%
import json
from collections import Counter
from typing import Dict, Tuple, List

def count_predicted_triplets(prediction_file: str, 
                             triplet_mapping: Dict[int, str], 
                             threshold: float = 0.5) -> Tuple[Dict[str, int], List[str]]:
    """
    Counts the frequency of predicted triplets based on a given threshold.
    
    Args:
        prediction_file (str): Path to the JSON prediction file.
        triplet_mapping (Dict[int, str]): Dictionary mapping triplet indices to names.
        threshold (float): Threshold to determine if a triplet is predicted.
    
    Returns:
        Tuple[Dict[str, int], List[str]]: 
            - Dictionary with triplet names as keys and their count as values.
            - List of missing triplets (triplets that are in the mapping but not predicted).
    """
    triplet_counter = Counter()

    # Load predictions from file
    with open(prediction_file, "r") as f:
        data = json.load(f)

    # Iterate over each frame prediction
    for frame_id, predictions in data.items():
        triplet_scores = predictions["triplet"]

        # Identify indices where the threshold is exceeded
        predicted_triplet_ids = [str(i+1) for i, score in enumerate(triplet_scores) if float(score) >= threshold]
        

        # Map indices to triplet names
        for triplet_id in predicted_triplet_ids:
            if triplet_id in triplet_mapping:
                triplet_name = triplet_mapping[triplet_id]
                triplet_counter[triplet_name] += 1
                
                print(f'frame_id {frame_id} - Contains {triplet_name}')
            else:
                raise ValueError(f"Triplet ID {triplet_id} not found in mapping.")

    # Identify missing triplets
    present_triplets = set(triplet_counter.keys())
    all_triplets = set(triplet_mapping.values())
    missing_triplets = sorted(all_triplets - present_triplets)

    return dict(triplet_counter), missing_triplets

# %%
# Example Usage:
prediction_file = "../results/cholecT50-challenge-old-ivtmetrics/results_rendezvous_l8_cholectcholect50-challenge_k0_batchnorm_lowres.json"  # Replace with actual file
triplet_mapping = TripletSegmentationVariables.categories['triplet']

predicted_counts, missing_predicted_triplets = count_predicted_triplets(prediction_file, triplet_mapping)
# Out:
# frame_id VID92_000097 - Contains grasper,grasp,specimen_bag
# frame_id VID92_000158 - Contains grasper,null_verb,null_target
# frame_id VID92_000159 - Contains grasper,null_verb,null_target
# frame_id VID92_000160 - Contains grasper,null_verb,null_target
# frame_id VID92_000162 - Contains grasper,null_verb,null_target
# frame_id VID92_000163 - Contains grasper,null_verb,null_target
# frame_id VID92_000165 - Contains grasper,null_verb,null_target
# frame_id VID92_000169 - Contains grasper,retract,gallbladder
# frame_id VID92_000171 - Contains grasper,null_verb,null_target
# frame_id VID92_000172 - Contains grasper,null_verb,null_target
# frame_id VID92_000175 - Contains grasper,null_verb,null_target
# frame_id VID92_000176 - Contains grasper,null_verb,null_target
# frame_id VID92_000177 - Contains grasper,null_verb,null_target
# frame_id VID92_000178 - Contains grasper,retract,omentum
# frame_id VID92_000178 - Contains grasper,null_verb,null_target
# frame_id VID92_000179 - Contains grasper,retract,omentum
# frame_id VID92_000179 - Contains grasper,null_verb,null_target
# frame_id VID92_000180 - Contains grasper,retract,omentum
# frame_id VID92_000180 - Contains grasper,null_verb,null_target
# frame_id VID92_000181 - Contains grasper,null_verb,null_target
# frame_id VID92_000182 - Contains grasper,null_verb,null_target
# frame_id VID92_000183 - Contains grasper,null_verb,null_target
# frame_id VID92_000184 - Contains grasper,null_verb,null_target
# frame_id VID92_000185 - Contains grasper,retract,gallbladder
# frame_id VID92_000185 - Contains grasper,null_verb,null_target
# frame_id VID92_000186 - Contains grasper,retract,gallbladder
# frame_id VID92_000186 - Contains grasper,retract,omentum
# frame_id VID92_000186 - Contains grasper,null_verb,null_target
# frame_id VID92_000187 - Contains grasper,null_verb,null_target
# frame_id VID92_000188 - Contains grasper,retract,omentum
# frame_id VID92_000189 - Contains grasper,retract,gallbladder
# frame_id VID92_000189 - Contains grasper,retract,omentum
# frame_id VID92_000189 - Contains grasper,null_verb,null_target
# frame_id VID92_000190 - Contains grasper,retract,gallbladder
# frame_id VID92_000190 - Contains grasper,retract,omentum
# frame_id VID92_000190 - Contains grasper,null_verb,null_target
# frame_id VID92_000191 - Contains grasper,retract,gallbladder
# frame_id VID92_000191 - Contains grasper,null_verb,null_target
# frame_id VID92_000192 - Contains grasper,retract,gallbladder
# frame_id VID92_000192 - Contains grasper,retract,omentum
# frame_id VID92_000192 - Contains grasper,null_verb,null_target
# frame_id VID92_000193 - Contains grasper,retract,gallbladder
# frame_id VID92_000194 - Contains grasper,null_verb,null_target
# frame_id VID92_000195 - Contains grasper,retract,gallbladder
# frame_id VID92_000195 - Contains grasper,null_verb,null_target
# frame_id VID92_000196 - Contains grasper,retract,gallbladder
# frame_id VID92_000196 - Contains grasper,retract,omentum
# frame_id VID92_000197 - Contains grasper,retract,gallbladder
# frame_id VID92_000197 - Contains grasper,null_verb,null_target
# frame_id VID92_000198 - Contains grasper,retract,gallbladder
# frame_id VID92_000199 - Contains grasper,retract,gallbladder
# frame_id VID92_000200 - Contains grasper,retract,gallbladder
# frame_id VID92_000201 - Contains grasper,retract,gallbladder
# frame_id VID92_000202 - Contains grasper,retract,gallbladder
# frame_id VID92_000203 - Contains grasper,retract,gallbladder
# frame_id VID92_000204 - Contains grasper,retract,gallbladder
# frame_id VID92_000204 - Contains grasper,null_verb,null_target
# frame_id VID92_000205 - Contains grasper,retract,gallbladder
# frame_id VID92_000206 - Contains grasper,retract,gallbladder
# frame_id VID92_000207 - Contains grasper,retract,gallbladder
# frame_id VID92_000208 - Contains grasper,retract,gallbladder
# frame_id VID92_000208 - Contains grasper,null_verb,null_target
# frame_id VID92_000209 - Contains grasper,retract,gallbladder
# frame_id VID92_000209 - Contains grasper,retract,omentum
# frame_id VID92_000210 - Contains grasper,retract,gallbladder
# frame_id VID92_000210 - Contains grasper,retract,omentum
# frame_id VID92_000211 - Contains grasper,retract,gallbladder
# frame_id VID92_000211 - Contains grasper,retract,omentum
# frame_id VID92_000212 - Contains grasper,retract,gallbladder
# frame_id VID92_000212 - Contains grasper,retract,omentum
# frame_id VID92_000213 - Contains grasper,retract,gallbladder
# frame_id VID92_000214 - Contains grasper,retract,gallbladder
# frame_id VID92_000215 - Contains grasper,retract,gallbladder
# frame_id VID92_000216 - Contains grasper,retract,gallbladder
# frame_id VID92_000242 - Contains grasper,retract,gallbladder
# frame_id VID92_000243 - Contains grasper,retract,gallbladder
# frame_id VID92_000244 - Contains grasper,retract,gallbladder
# frame_id VID92_000245 - Contains grasper,retract,gallbladder
# frame_id VID92_000246 - Contains grasper,retract,gallbladder
# frame_id VID92_000247 - Contains grasper,retract,gallbladder
# frame_id VID92_000248 - Contains grasper,retract,gallbladder
# frame_id VID92_000249 - Contains grasper,retract,gallbladder
# frame_id VID92_000250 - Contains grasper,grasp,gallbladder
# frame_id VID92_000250 - Contains grasper,retract,gallbladder
# frame_id VID92_000251 - Contains grasper,retract,gallbladder
# frame_id VID92_000252 - Contains grasper,retract,gallbladder
# frame_id VID92_000253 - Contains grasper,retract,gallbladder
# frame_id VID92_000253 - Contains grasper,null_verb,null_target
# frame_id VID92_000254 - Contains grasper,retract,gallbladder
# frame_id VID92_000255 - Contains grasper,retract,gallbladder
# frame_id VID92_000256 - Contains grasper,retract,gallbladder
# frame_id VID92_000257 - Contains grasper,retract,gallbladder
# frame_id VID92_000258 - Contains grasper,retract,gallbladder
# frame_id VID92_000259 - Contains grasper,retract,gallbladder
# frame_id VID92_000259 - Contains grasper,retract,omentum
# frame_id VID92_000260 - Contains grasper,retract,gallbladder
# frame_id VID92_000260 - Contains grasper,retract,omentum
# frame_id VID92_000261 - Contains grasper,retract,gallbladder
# frame_id VID92_000261 - Contains grasper,retract,omentum
# frame_id VID92_000261 - Contains grasper,null_verb,null_target
# frame_id VID92_000262 - Contains grasper,retract,gallbladder
# frame_id VID92_000262 - Contains grasper,retract,omentum
# frame_id VID92_000262 - Contains grasper,null_verb,null_target
# frame_id VID92_000263 - Contains grasper,retract,gallbladder
# frame_id VID92_000263 - Contains grasper,retract,omentum
# frame_id VID92_000264 - Contains grasper,retract,gallbladder
# frame_id VID92_000264 - Contains grasper,retract,omentum
# frame_id VID92_000265 - Contains grasper,retract,gallbladder
# frame_id VID92_000265 - Contains grasper,retract,omentum
# frame_id VID92_000265 - Contains grasper,null_verb,null_target
# frame_id VID92_000266 - Contains grasper,retract,gallbladder
# frame_id VID92_000266 - Contains grasper,retract,omentum
# frame_id VID92_000266 - Contains grasper,null_verb,null_target
# frame_id VID92_000267 - Contains grasper,retract,gallbladder
# frame_id VID92_000267 - Contains grasper,retract,omentum
# frame_id VID92_000267 - Contains grasper,null_verb,null_target
# frame_id VID92_000268 - Contains grasper,retract,gallbladder
# frame_id VID92_000268 - Contains grasper,null_verb,null_target
# frame_id VID92_000269 - Contains grasper,retract,gallbladder
# frame_id VID92_000269 - Contains grasper,retract,omentum
# frame_id VID92_000270 - Contains grasper,retract,gallbladder
# frame_id VID92_000270 - Contains grasper,retract,omentum
# frame_id VID92_000270 - Contains grasper,null_verb,null_target
# frame_id VID92_000271 - Contains grasper,retract,gallbladder
# frame_id VID92_000271 - Contains grasper,retract,omentum
# frame_id VID92_000271 - Contains grasper,null_verb,null_target
# frame_id VID92_000272 - Contains grasper,retract,gallbladder
# frame_id VID92_000272 - Contains grasper,retract,omentum
# frame_id VID92_000272 - Contains grasper,null_verb,null_target
# frame_id VID92_000273 - Contains grasper,retract,gallbladder
# frame_id VID92_000273 - Contains grasper,retract,omentum
# frame_id VID92_000273 - Contains grasper,null_verb,null_target
# frame_id VID92_000274 - Contains grasper,retract,gallbladder
# frame_id VID92_000274 - Contains grasper,retract,omentum
# frame_id VID92_000274 - Contains grasper,null_verb,null_target
# frame_id VID92_000275 - Contains grasper,retract,gallbladder
# frame_id VID92_000275 - Contains grasper,retract,omentum
# frame_id VID92_000275 - Contains grasper,null_verb,null_target
# frame_id VID92_000276 - Contains grasper,retract,gallbladder
# frame_id VID92_000276 - Contains grasper,null_verb,null_target
# frame_id VID92_000277 - Contains grasper,retract,gallbladder
# frame_id VID92_000277 - Contains grasper,retract,omentum
# frame_id VID92_000277 - Contains grasper,null_verb,null_target
# frame_id VID92_000278 - Contains grasper,retract,gallbladder
# frame_id VID92_000278 - Contains grasper,null_verb,null_target
# frame_id VID92_000279 - Contains grasper,retract,gallbladder
# frame_id VID92_000279 - Contains grasper,retract,omentum
# frame_id VID92_000279 - Contains grasper,null_verb,null_target
# frame_id VID92_000280 - Contains grasper,retract,gallbladder
# frame_id VID92_000280 - Contains grasper,null_verb,null_target
# frame_id VID92_000281 - Contains grasper,retract,gallbladder
# frame_id VID92_000281 - Contains grasper,null_verb,null_target
# frame_id VID92_000282 - Contains grasper,retract,gallbladder
# frame_id VID92_000282 - Contains grasper,null_verb,null_target
# frame_id VID92_000283 - Contains grasper,retract,gallbladder
# frame_id VID92_000283 - Contains grasper,retract,omentum
# frame_id VID92_000283 - Contains grasper,null_verb,null_target
# frame_id VID92_000284 - Contains grasper,retract,gallbladder
# frame_id VID92_000284 - Contains grasper,retract,omentum
# frame_id VID92_000284 - Contains grasper,null_verb,null_target
# frame_id VID92_000285 - Contains grasper,retract,gallbladder
# frame_id VID92_000285 - Contains grasper,retract,omentum
# frame_id VID92_000286 - Contains grasper,retract,gallbladder
# frame_id VID92_000286 - Contains grasper,retract,omentum
# frame_id VID92_000287 - Contains grasper,retract,gallbladder
# frame_id VID92_000287 - Contains grasper,retract,omentum
# frame_id VID92_000287 - Contains grasper,null_verb,null_target
# frame_id VID92_000288 - Contains grasper,retract,gallbladder
# frame_id VID92_000288 - Contains grasper,retract,omentum
# frame_id VID92_000288 - Contains grasper,null_verb,null_target
# frame_id VID92_000289 - Contains grasper,retract,gallbladder
# frame_id VID92_000289 - Contains grasper,retract,omentum
# frame_id VID92_000289 - Contains grasper,null_verb,null_target
# frame_id VID92_000290 - Contains grasper,retract,gallbladder
# frame_id VID92_000290 - Contains grasper,retract,omentum
# frame_id VID92_000290 - Contains grasper,null_verb,null_target
# frame_id VID92_000291 - Contains grasper,retract,gallbladder
# frame_id VID92_000291 - Contains grasper,retract,omentum
# frame_id VID92_000291 - Contains grasper,null_verb,null_target
# frame_id VID92_000292 - Contains grasper,retract,gallbladder
# frame_id VID92_000292 - Contains grasper,null_verb,null_target
# frame_id VID92_000293 - Contains grasper,retract,gallbladder
# frame_id VID92_000293 - Contains grasper,null_verb,null_target
# frame_id VID92_000294 - Contains grasper,retract,gallbladder
# frame_id VID92_000294 - Contains grasper,null_verb,null_target
# frame_id VID92_000295 - Contains grasper,retract,gallbladder
# frame_id VID92_000295 - Contains grasper,null_verb,null_target
# frame_id VID92_000296 - Contains grasper,retract,gallbladder
# frame_id VID92_000296 - Contains grasper,null_verb,null_target
# frame_id VID92_000297 - Contains grasper,retract,gallbladder
# frame_id VID92_000298 - Contains grasper,retract,gallbladder
# frame_id VID92_000298 - Contains grasper,retract,omentum
# frame_id VID92_000298 - Contains hook,dissect,omentum
# frame_id VID92_000299 - Contains grasper,retract,gallbladder
# frame_id VID92_000299 - Contains grasper,retract,omentum
# frame_id VID92_000300 - Contains grasper,retract,gallbladder
# frame_id VID92_000300 - Contains grasper,retract,omentum
# frame_id VID92_000300 - Contains hook,dissect,omentum
# frame_id VID92_000301 - Contains grasper,retract,gallbladder
# frame_id VID92_000301 - Contains grasper,retract,omentum
# frame_id VID92_000301 - Contains hook,dissect,gallbladder
# frame_id VID92_000302 - Contains grasper,retract,gallbladder
# frame_id VID92_000302 - Contains grasper,retract,omentum
# frame_id VID92_000302 - Contains hook,dissect,gallbladder
# frame_id VID92_000303 - Contains grasper,retract,omentum
# frame_id VID92_000304 - Contains grasper,retract,omentum
# frame_id VID92_000304 - Contains hook,dissect,omentum
# frame_id VID92_000305 - Contains grasper,retract,gallbladder
# frame_id VID92_000305 - Contains grasper,retract,omentum
# frame_id VID92_000305 - Contains hook,dissect,omentum
# frame_id VID92_000306 - Contains grasper,retract,gallbladder
# frame_id VID92_000306 - Contains grasper,retract,omentum
# frame_id VID92_000306 - Contains hook,dissect,omentum
# frame_id VID92_000307 - Contains grasper,retract,gallbladder
# frame_id VID92_000307 - Contains grasper,retract,omentum
# frame_id VID92_000307 - Contains hook,dissect,omentum
# frame_id VID92_000308 - Contains grasper,retract,gallbladder
# frame_id VID92_000308 - Contains grasper,retract,omentum
# frame_id VID92_000308 - Contains hook,dissect,omentum
# frame_id VID92_000309 - Contains grasper,retract,gallbladder
# frame_id VID92_000309 - Contains grasper,retract,omentum
# frame_id VID92_000309 - Contains hook,dissect,omentum
# frame_id VID92_000310 - Contains grasper,retract,gallbladder
# frame_id VID92_000310 - Contains grasper,retract,omentum
# frame_id VID92_000310 - Contains hook,dissect,omentum
# frame_id VID92_000311 - Contains grasper,retract,gallbladder
# frame_id VID92_000311 - Contains grasper,retract,omentum
# frame_id VID92_000311 - Contains hook,dissect,omentum
# frame_id VID92_000312 - Contains grasper,retract,gallbladder
# frame_id VID92_000312 - Contains grasper,retract,omentum
# frame_id VID92_000312 - Contains hook,dissect,omentum
# frame_id VID92_000313 - Contains grasper,retract,gallbladder
# frame_id VID92_000313 - Contains grasper,retract,omentum
# frame_id VID92_000313 - Contains hook,dissect,omentum
# frame_id VID92_000314 - Contains grasper,retract,gallbladder
# frame_id VID92_000314 - Contains grasper,retract,omentum
# frame_id VID92_000314 - Contains hook,dissect,omentum
# frame_id VID92_000315 - Contains grasper,retract,gallbladder
# frame_id VID92_000315 - Contains grasper,retract,omentum
# frame_id VID92_000315 - Contains hook,dissect,omentum
# frame_id VID92_000316 - Contains grasper,retract,gallbladder
# frame_id VID92_000316 - Contains grasper,retract,omentum
# frame_id VID92_000316 - Contains hook,dissect,omentum
# frame_id VID92_000317 - Contains grasper,retract,gallbladder
# frame_id VID92_000317 - Contains grasper,retract,omentum
# frame_id VID92_000317 - Contains hook,dissect,omentum
# frame_id VID92_000318 - Contains grasper,retract,gallbladder
# frame_id VID92_000318 - Contains grasper,retract,omentum
# frame_id VID92_000318 - Contains hook,dissect,omentum
# frame_id VID92_000319 - Contains grasper,retract,gallbladder
# frame_id VID92_000319 - Contains grasper,retract,omentum
# frame_id VID92_000319 - Contains hook,dissect,omentum
# frame_id VID92_000320 - Contains grasper,retract,gallbladder
# frame_id VID92_000320 - Contains grasper,retract,omentum
# frame_id VID92_000320 - Contains hook,dissect,omentum
# frame_id VID92_000321 - Contains grasper,retract,gallbladder
# frame_id VID92_000321 - Contains grasper,retract,omentum
# frame_id VID92_000321 - Contains hook,dissect,gallbladder
# frame_id VID92_000321 - Contains hook,dissect,omentum
# frame_id VID92_000322 - Contains grasper,retract,gallbladder
# frame_id VID92_000322 - Contains grasper,retract,omentum
# frame_id VID92_000322 - Contains hook,dissect,gallbladder
# frame_id VID92_000323 - Contains grasper,retract,gallbladder
# frame_id VID92_000323 - Contains grasper,retract,omentum
# frame_id VID92_000323 - Contains hook,dissect,omentum
# frame_id VID92_000324 - Contains grasper,retract,gallbladder
# frame_id VID92_000324 - Contains grasper,retract,omentum
# frame_id VID92_000324 - Contains hook,dissect,gallbladder
# frame_id VID92_000325 - Contains grasper,retract,gallbladder
# frame_id VID92_000325 - Contains grasper,retract,omentum
# frame_id VID92_000325 - Contains hook,dissect,gallbladder
# frame_id VID92_000326 - Contains grasper,retract,gallbladder
# frame_id VID92_000326 - Contains hook,dissect,gallbladder
# frame_id VID92_000327 - Contains grasper,retract,gallbladder
# frame_id VID92_000327 - Contains grasper,retract,omentum
# frame_id VID92_000327 - Contains hook,dissect,gallbladder
# frame_id VID92_000328 - Contains grasper,retract,gallbladder
# frame_id VID92_000328 - Contains grasper,retract,omentum
# frame_id VID92_000329 - Contains grasper,retract,gallbladder
# frame_id VID92_000329 - Contains grasper,retract,omentum
# frame_id VID92_000330 - Contains grasper,retract,gallbladder
# frame_id VID92_000330 - Contains hook,dissect,gallbladder
# frame_id VID92_000331 - Contains grasper,retract,gallbladder
# frame_id VID92_000331 - Contains grasper,retract,omentum
# frame_id VID92_000331 - Contains hook,dissect,omentum
# frame_id VID92_000332 - Contains grasper,retract,gallbladder
# frame_id VID92_000332 - Contains hook,dissect,omentum
# frame_id VID92_000333 - Contains grasper,retract,gallbladder
# frame_id VID92_000333 - Contains hook,dissect,omentum
# frame_id VID92_000334 - Contains grasper,retract,gallbladder
# frame_id VID92_000334 - Contains hook,dissect,omentum
# frame_id VID92_000335 - Contains grasper,retract,gallbladder
# frame_id VID92_000335 - Contains hook,dissect,omentum
# frame_id VID92_000336 - Contains grasper,retract,gallbladder
# frame_id VID92_000336 - Contains hook,dissect,omentum
# frame_id VID92_000337 - Contains grasper,retract,gallbladder
# frame_id VID92_000338 - Contains grasper,retract,gallbladder
# frame_id VID92_000338 - Contains hook,dissect,omentum
# frame_id VID92_000339 - Contains grasper,retract,gallbladder
# frame_id VID92_000339 - Contains hook,dissect,omentum
# frame_id VID92_000340 - Contains grasper,retract,gallbladder
# frame_id VID92_000340 - Contains hook,dissect,omentum
# frame_id VID92_000341 - Contains grasper,retract,gallbladder
# frame_id VID92_000341 - Contains hook,dissect,omentum
# frame_id VID92_000342 - Contains grasper,retract,gallbladder
# frame_id VID92_000342 - Contains hook,dissect,gallbladder
# frame_id VID92_000343 - Contains grasper,retract,gallbladder
# frame_id VID92_000343 - Contains hook,dissect,gallbladder
# frame_id VID92_000343 - Contains hook,dissect,omentum
# frame_id VID92_000344 - Contains grasper,retract,gallbladder
# frame_id VID92_000344 - Contains hook,dissect,gallbladder
# frame_id VID92_000345 - Contains grasper,retract,gallbladder
# frame_id VID92_000345 - Contains hook,dissect,gallbladder
# frame_id VID92_000345 - Contains hook,dissect,omentum
# frame_id VID92_000346 - Contains grasper,retract,gallbladder
# frame_id VID92_000346 - Contains hook,dissect,gallbladder
# frame_id VID92_000347 - Contains grasper,retract,gallbladder
# frame_id VID92_000347 - Contains hook,dissect,gallbladder
# frame_id VID92_000348 - Contains grasper,retract,gallbladder
# frame_id VID92_000348 - Contains hook,dissect,gallbladder
# frame_id VID92_000349 - Contains grasper,retract,gallbladder
# frame_id VID92_000349 - Contains hook,dissect,gallbladder
# frame_id VID92_000350 - Contains grasper,retract,gallbladder
# frame_id VID92_000350 - Contains hook,dissect,gallbladder
# frame_id VID92_000351 - Contains grasper,retract,gallbladder
# frame_id VID92_000351 - Contains hook,dissect,gallbladder
# frame_id VID92_000352 - Contains grasper,retract,gallbladder
# frame_id VID92_000352 - Contains grasper,retract,omentum
# frame_id VID92_000352 - Contains hook,dissect,gallbladder
# frame_id VID92_000352 - Contains hook,dissect,omentum
# frame_id VID92_000353 - Contains grasper,retract,gallbladder
# frame_id VID92_000353 - Contains hook,dissect,gallbladder
# frame_id VID92_000354 - Contains grasper,retract,gallbladder
# frame_id VID92_000354 - Contains hook,dissect,gallbladder
# frame_id VID92_000354 - Contains hook,dissect,omentum
# frame_id VID92_000355 - Contains grasper,retract,gallbladder
# frame_id VID92_000355 - Contains hook,dissect,gallbladder
# frame_id VID92_000356 - Contains grasper,retract,gallbladder
# frame_id VID92_000356 - Contains hook,dissect,gallbladder
# frame_id VID92_000357 - Contains grasper,retract,gallbladder
# frame_id VID92_000357 - Contains hook,dissect,omentum
# frame_id VID92_000358 - Contains grasper,retract,gallbladder
# frame_id VID92_000358 - Contains hook,dissect,gallbladder
# frame_id VID92_000359 - Contains grasper,retract,gallbladder
# frame_id VID92_000359 - Contains hook,dissect,omentum
# frame_id VID92_000360 - Contains grasper,retract,gallbladder
# frame_id VID92_000360 - Contains hook,dissect,gallbladder
# frame_id VID92_000361 - Contains grasper,retract,gallbladder
# frame_id VID92_000361 - Contains hook,dissect,omentum
# frame_id VID92_000362 - Contains grasper,retract,gallbladder
# frame_id VID92_000362 - Contains hook,dissect,gallbladder
# frame_id VID92_000363 - Contains grasper,retract,gallbladder
# frame_id VID92_000363 - Contains hook,dissect,gallbladder
# frame_id VID92_000364 - Contains grasper,retract,gallbladder
# frame_id VID92_000364 - Contains hook,dissect,omentum
# frame_id VID92_000365 - Contains grasper,retract,gallbladder
# frame_id VID92_000365 - Contains hook,dissect,gallbladder
# frame_id VID92_000365 - Contains hook,dissect,omentum
# frame_id VID92_000366 - Contains grasper,retract,gallbladder
# frame_id VID92_000366 - Contains hook,dissect,gallbladder
# frame_id VID92_000367 - Contains grasper,retract,gallbladder
# frame_id VID92_000367 - Contains hook,dissect,gallbladder
# frame_id VID92_000368 - Contains grasper,retract,gallbladder
# frame_id VID92_000368 - Contains hook,dissect,gallbladder
# frame_id VID92_000369 - Contains grasper,retract,gallbladder
# frame_id VID92_000369 - Contains hook,dissect,omentum
# frame_id VID92_000370 - Contains grasper,retract,gallbladder
# frame_id VID92_000370 - Contains hook,dissect,omentum
# frame_id VID92_000371 - Contains grasper,retract,gallbladder
# frame_id VID92_000371 - Contains hook,dissect,gallbladder
# frame_id VID92_000371 - Contains hook,dissect,omentum
# frame_id VID92_000372 - Contains grasper,retract,gallbladder
# frame_id VID92_000372 - Contains hook,dissect,omentum
# frame_id VID92_000373 - Contains grasper,retract,gallbladder
# frame_id VID92_000373 - Contains hook,dissect,gallbladder
# frame_id VID92_000374 - Contains grasper,retract,gallbladder
# frame_id VID92_000374 - Contains hook,dissect,gallbladder
# frame_id VID92_000375 - Contains grasper,retract,gallbladder
# frame_id VID92_000375 - Contains hook,dissect,gallbladder
# frame_id VID92_000375 - Contains hook,dissect,omentum
# frame_id VID92_000376 - Contains grasper,retract,gallbladder
# frame_id VID92_000376 - Contains hook,dissect,gallbladder
# frame_id VID92_000377 - Contains grasper,retract,gallbladder
# frame_id VID92_000377 - Contains hook,dissect,gallbladder
# frame_id VID92_000378 - Contains grasper,retract,gallbladder
# frame_id VID92_000378 - Contains hook,dissect,omentum
# frame_id VID92_000379 - Contains grasper,retract,gallbladder
# frame_id VID92_000379 - Contains hook,dissect,omentum
# frame_id VID92_000380 - Contains grasper,retract,gallbladder
# frame_id VID92_000380 - Contains hook,dissect,omentum
# frame_id VID92_000381 - Contains grasper,retract,gallbladder
# frame_id VID92_000381 - Contains hook,dissect,omentum
# frame_id VID92_000382 - Contains hook,dissect,gallbladder
# frame_id VID92_000383 - Contains hook,dissect,gallbladder
# frame_id VID92_000384 - Contains hook,dissect,gallbladder
# frame_id VID92_000385 - Contains hook,dissect,gallbladder
# frame_id VID92_000387 - Contains hook,dissect,omentum
# frame_id VID92_000388 - Contains grasper,retract,gallbladder
# frame_id VID92_000388 - Contains hook,dissect,omentum
# frame_id VID92_000389 - Contains grasper,retract,gallbladder
# frame_id VID92_000389 - Contains hook,dissect,gallbladder
# frame_id VID92_000390 - Contains grasper,retract,gallbladder
# frame_id VID92_000390 - Contains hook,dissect,gallbladder
# frame_id VID92_000391 - Contains hook,dissect,gallbladder
# frame_id VID92_000393 - Contains hook,dissect,gallbladder
# frame_id VID92_000394 - Contains hook,dissect,gallbladder
# frame_id VID92_000394 - Contains hook,dissect,omentum
# frame_id VID92_000395 - Contains grasper,retract,gallbladder
# frame_id VID92_000395 - Contains hook,dissect,omentum
# frame_id VID92_000396 - Contains grasper,retract,gallbladder
# frame_id VID92_000396 - Contains hook,dissect,omentum
# frame_id VID92_000397 - Contains hook,dissect,omentum
# frame_id VID92_000398 - Contains hook,dissect,omentum
# frame_id VID92_000399 - Contains hook,dissect,omentum
# frame_id VID92_000400 - Contains hook,dissect,gallbladder
# frame_id VID92_000400 - Contains hook,dissect,omentum
# frame_id VID92_000401 - Contains hook,dissect,gallbladder
# frame_id VID92_000402 - Contains grasper,retract,gallbladder
# frame_id VID92_000402 - Contains hook,dissect,omentum
# frame_id VID92_000403 - Contains hook,dissect,gallbladder
# frame_id VID92_000404 - Contains hook,dissect,gallbladder
# frame_id VID92_000405 - Contains grasper,retract,gallbladder
# frame_id VID92_000405 - Contains hook,dissect,omentum
# frame_id VID92_000406 - Contains grasper,retract,gallbladder
# frame_id VID92_000406 - Contains hook,dissect,omentum
# frame_id VID92_000407 - Contains hook,dissect,omentum
# frame_id VID92_000408 - Contains hook,dissect,gallbladder
# frame_id VID92_000409 - Contains grasper,retract,gallbladder
# frame_id VID92_000409 - Contains hook,dissect,gallbladder
# frame_id VID92_000410 - Contains grasper,retract,gallbladder
# frame_id VID92_000410 - Contains hook,dissect,gallbladder
# frame_id VID92_000411 - Contains grasper,retract,gallbladder
# frame_id VID92_000411 - Contains hook,dissect,cystic_duct
# frame_id VID92_000412 - Contains hook,dissect,omentum
# frame_id VID92_000413 - Contains grasper,retract,gallbladder
# frame_id VID92_000414 - Contains grasper,retract,gallbladder
# frame_id VID92_000414 - Contains hook,dissect,omentum
# frame_id VID92_000415 - Contains grasper,retract,gallbladder
# frame_id VID92_000416 - Contains grasper,retract,gallbladder
# frame_id VID92_000416 - Contains hook,dissect,omentum
# frame_id VID92_000417 - Contains grasper,retract,gallbladder
# frame_id VID92_000418 - Contains grasper,retract,gallbladder
# frame_id VID92_000418 - Contains hook,dissect,omentum
# frame_id VID92_000419 - Contains grasper,retract,gallbladder
# frame_id VID92_000419 - Contains hook,dissect,gallbladder
# frame_id VID92_000420 - Contains hook,dissect,omentum
# frame_id VID92_000421 - Contains hook,dissect,omentum
# frame_id VID92_000422 - Contains grasper,retract,gallbladder
# frame_id VID92_000422 - Contains hook,dissect,omentum
# frame_id VID92_000423 - Contains grasper,retract,gallbladder
# frame_id VID92_000423 - Contains grasper,retract,omentum
# frame_id VID92_000423 - Contains hook,dissect,omentum
# frame_id VID92_000424 - Contains grasper,retract,gallbladder
# frame_id VID92_000424 - Contains hook,dissect,omentum
# frame_id VID92_000425 - Contains grasper,retract,gallbladder
# frame_id VID92_000425 - Contains grasper,retract,omentum
# frame_id VID92_000425 - Contains hook,dissect,omentum
# frame_id VID92_000426 - Contains grasper,retract,gallbladder
# frame_id VID92_000426 - Contains hook,dissect,omentum
# frame_id VID92_000427 - Contains grasper,retract,gallbladder
# frame_id VID92_000427 - Contains hook,dissect,omentum
# frame_id VID92_000428 - Contains grasper,retract,gallbladder
# frame_id VID92_000428 - Contains hook,dissect,omentum
# frame_id VID92_000429 - Contains grasper,retract,gallbladder
# frame_id VID92_000429 - Contains hook,dissect,omentum
# frame_id VID92_000430 - Contains grasper,retract,gallbladder
# frame_id VID92_000430 - Contains hook,dissect,cystic_duct
# frame_id VID92_000430 - Contains hook,dissect,omentum
# frame_id VID92_000431 - Contains grasper,retract,gallbladder
# frame_id VID92_000431 - Contains hook,dissect,omentum
# frame_id VID92_000432 - Contains hook,dissect,omentum
# frame_id VID92_000433 - Contains grasper,retract,gallbladder
# frame_id VID92_000433 - Contains hook,dissect,omentum
# frame_id VID92_000434 - Contains grasper,retract,gallbladder
# frame_id VID92_000435 - Contains grasper,retract,gallbladder
# frame_id VID92_000435 - Contains hook,dissect,omentum
# frame_id VID92_000436 - Contains grasper,retract,gallbladder
# frame_id VID92_000436 - Contains hook,dissect,omentum
# frame_id VID92_000437 - Contains grasper,retract,gallbladder
# frame_id VID92_000437 - Contains hook,dissect,omentum
# frame_id VID92_000438 - Contains grasper,retract,gallbladder
# frame_id VID92_000438 - Contains hook,dissect,omentum
# frame_id VID92_000439 - Contains grasper,retract,gallbladder
# frame_id VID92_000439 - Contains hook,dissect,omentum
# frame_id VID92_000440 - Contains grasper,retract,gallbladder
# frame_id VID92_000441 - Contains grasper,retract,gallbladder
# frame_id VID92_000441 - Contains hook,dissect,gallbladder
# frame_id VID92_000442 - Contains grasper,retract,gallbladder
# frame_id VID92_000442 - Contains hook,dissect,omentum
# frame_id VID92_000443 - Contains grasper,retract,gallbladder
# frame_id VID92_000443 - Contains hook,dissect,gallbladder
# frame_id VID92_000443 - Contains hook,dissect,omentum
# frame_id VID92_000444 - Contains grasper,retract,gallbladder
# frame_id VID92_000444 - Contains hook,dissect,omentum
# frame_id VID92_000445 - Contains grasper,retract,gallbladder
# frame_id VID92_000445 - Contains hook,dissect,omentum
# frame_id VID92_000446 - Contains grasper,retract,gallbladder
# frame_id VID92_000447 - Contains grasper,retract,gallbladder
# frame_id VID92_000447 - Contains hook,dissect,omentum
# frame_id VID92_000448 - Contains grasper,retract,gallbladder
# frame_id VID92_000448 - Contains hook,dissect,omentum
# frame_id VID92_000449 - Contains grasper,retract,gallbladder
# frame_id VID92_000449 - Contains hook,dissect,omentum
# frame_id VID92_000450 - Contains grasper,retract,gallbladder
# frame_id VID92_000450 - Contains hook,dissect,omentum
# frame_id VID92_000451 - Contains grasper,retract,gallbladder
# frame_id VID92_000451 - Contains hook,dissect,omentum
# frame_id VID92_000452 - Contains grasper,retract,gallbladder
# frame_id VID92_000452 - Contains hook,dissect,omentum
# frame_id VID92_000453 - Contains grasper,retract,gallbladder
# frame_id VID92_000453 - Contains hook,dissect,gallbladder
# frame_id VID92_000454 - Contains grasper,retract,gallbladder
# frame_id VID92_000455 - Contains grasper,retract,gallbladder
# frame_id VID92_000456 - Contains grasper,retract,gallbladder
# frame_id VID92_000457 - Contains grasper,retract,gallbladder
# frame_id VID92_000457 - Contains hook,dissect,omentum
# frame_id VID92_000458 - Contains grasper,retract,gallbladder
# frame_id VID92_000458 - Contains hook,dissect,omentum
# frame_id VID92_000459 - Contains grasper,retract,gallbladder
# frame_id VID92_000459 - Contains hook,dissect,omentum
# frame_id VID92_000460 - Contains hook,dissect,omentum
# frame_id VID92_000461 - Contains grasper,retract,gallbladder
# frame_id VID92_000461 - Contains grasper,retract,omentum
# frame_id VID92_000461 - Contains hook,dissect,omentum
# frame_id VID92_000462 - Contains grasper,retract,omentum
# frame_id VID92_000462 - Contains hook,dissect,omentum
# frame_id VID92_000463 - Contains grasper,retract,gallbladder
# frame_id VID92_000464 - Contains grasper,retract,gallbladder
# frame_id VID92_000464 - Contains grasper,retract,omentum
# frame_id VID92_000464 - Contains hook,dissect,omentum
# frame_id VID92_000465 - Contains grasper,retract,omentum
# frame_id VID92_000465 - Contains hook,dissect,omentum
# frame_id VID92_000466 - Contains grasper,retract,gallbladder
# frame_id VID92_000466 - Contains hook,dissect,gallbladder
# frame_id VID92_000467 - Contains grasper,retract,gallbladder
# frame_id VID92_000467 - Contains grasper,retract,omentum
# frame_id VID92_000467 - Contains hook,dissect,omentum
# frame_id VID92_000468 - Contains grasper,retract,gallbladder
# frame_id VID92_000469 - Contains grasper,retract,gallbladder
# frame_id VID92_000469 - Contains grasper,retract,omentum
# frame_id VID92_000469 - Contains hook,dissect,gallbladder
# frame_id VID92_000470 - Contains grasper,retract,gallbladder
# frame_id VID92_000470 - Contains grasper,retract,omentum
# frame_id VID92_000471 - Contains grasper,retract,gallbladder
# frame_id VID92_000471 - Contains hook,dissect,omentum
# frame_id VID92_000472 - Contains grasper,retract,gallbladder
# frame_id VID92_000472 - Contains hook,dissect,omentum
# frame_id VID92_000473 - Contains grasper,retract,gallbladder
# frame_id VID92_000474 - Contains grasper,retract,gallbladder
# frame_id VID92_000474 - Contains hook,dissect,omentum
# frame_id VID92_000475 - Contains grasper,retract,gallbladder
# frame_id VID92_000475 - Contains grasper,retract,omentum
# frame_id VID92_000475 - Contains hook,dissect,omentum
# frame_id VID92_000476 - Contains grasper,retract,gallbladder
# frame_id VID92_000476 - Contains hook,dissect,gallbladder
# frame_id VID92_000478 - Contains hook,dissect,omentum
# frame_id VID92_000479 - Contains grasper,retract,omentum
# frame_id VID92_000479 - Contains hook,dissect,omentum
# frame_id VID92_000480 - Contains grasper,retract,gallbladder
# frame_id VID92_000480 - Contains hook,dissect,omentum
# frame_id VID92_000481 - Contains hook,dissect,omentum
# frame_id VID92_000482 - Contains grasper,retract,gallbladder
# frame_id VID92_000482 - Contains hook,dissect,omentum
# frame_id VID92_000483 - Contains grasper,retract,gallbladder
# frame_id VID92_000483 - Contains grasper,retract,omentum
# frame_id VID92_000483 - Contains hook,dissect,omentum
# frame_id VID92_000484 - Contains grasper,retract,gallbladder
# frame_id VID92_000485 - Contains grasper,retract,gallbladder
# frame_id VID92_000485 - Contains hook,dissect,omentum
# frame_id VID92_000486 - Contains grasper,retract,gallbladder
# frame_id VID92_000486 - Contains grasper,retract,omentum
# frame_id VID92_000486 - Contains hook,dissect,omentum
# frame_id VID92_000487 - Contains grasper,retract,gallbladder
# frame_id VID92_000487 - Contains hook,dissect,omentum
# frame_id VID92_000488 - Contains grasper,retract,gallbladder
# frame_id VID92_000488 - Contains hook,dissect,gallbladder
# frame_id VID92_000489 - Contains grasper,retract,gallbladder
# frame_id VID92_000489 - Contains grasper,retract,omentum
# frame_id VID92_000490 - Contains hook,dissect,omentum
# frame_id VID92_000491 - Contains grasper,retract,gallbladder
# frame_id VID92_000491 - Contains hook,dissect,cystic_duct
# frame_id VID92_000491 - Contains hook,dissect,omentum
# frame_id VID92_000493 - Contains grasper,retract,gallbladder
# frame_id VID92_000494 - Contains hook,dissect,omentum
# frame_id VID92_000495 - Contains grasper,retract,gallbladder
# frame_id VID92_000495 - Contains hook,dissect,gallbladder
# frame_id VID92_000496 - Contains grasper,retract,gallbladder
# frame_id VID92_000496 - Contains hook,dissect,omentum
# frame_id VID92_000497 - Contains grasper,retract,omentum
# frame_id VID92_000497 - Contains hook,dissect,omentum
# frame_id VID92_000498 - Contains hook,dissect,cystic_duct
# frame_id VID92_000499 - Contains grasper,retract,omentum
# frame_id VID92_000499 - Contains hook,dissect,gallbladder
# frame_id VID92_000500 - Contains grasper,retract,gallbladder
# frame_id VID92_000500 - Contains hook,dissect,gallbladder
# frame_id VID92_000501 - Contains grasper,retract,gallbladder
# frame_id VID92_000501 - Contains hook,dissect,gallbladder
# frame_id VID92_000502 - Contains grasper,retract,gallbladder
# frame_id VID92_000503 - Contains grasper,retract,gallbladder
# frame_id VID92_000503 - Contains hook,dissect,gallbladder
# frame_id VID92_000503 - Contains hook,dissect,omentum
# frame_id VID92_000504 - Contains hook,dissect,gallbladder
# frame_id VID92_000504 - Contains hook,dissect,omentum
# frame_id VID92_000505 - Contains grasper,retract,gallbladder
# frame_id VID92_000505 - Contains grasper,retract,omentum
# frame_id VID92_000505 - Contains hook,dissect,gallbladder
# frame_id VID92_000505 - Contains hook,dissect,omentum
# frame_id VID92_000506 - Contains grasper,retract,gallbladder
# frame_id VID92_000506 - Contains hook,dissect,gallbladder
# frame_id VID92_000507 - Contains grasper,retract,gallbladder
# frame_id VID92_000508 - Contains grasper,retract,gallbladder
# frame_id VID92_000508 - Contains grasper,retract,omentum
# frame_id VID92_000508 - Contains hook,dissect,gallbladder
# frame_id VID92_000509 - Contains grasper,retract,gallbladder
# frame_id VID92_000509 - Contains grasper,retract,omentum
# frame_id VID92_000509 - Contains hook,dissect,gallbladder
# frame_id VID92_000509 - Contains hook,dissect,omentum
# frame_id VID92_000511 - Contains hook,dissect,gallbladder
# frame_id VID92_000512 - Contains hook,dissect,gallbladder
# frame_id VID92_000513 - Contains hook,dissect,gallbladder
# frame_id VID92_000514 - Contains hook,dissect,gallbladder
# frame_id VID92_000515 - Contains hook,dissect,gallbladder
# frame_id VID92_000516 - Contains grasper,retract,gallbladder
# frame_id VID92_000516 - Contains hook,dissect,omentum
# frame_id VID92_000517 - Contains grasper,retract,gallbladder
# frame_id VID92_000517 - Contains hook,dissect,gallbladder
# frame_id VID92_000518 - Contains grasper,retract,gallbladder
# frame_id VID92_000518 - Contains hook,dissect,gallbladder
# frame_id VID92_000519 - Contains grasper,retract,gallbladder
# frame_id VID92_000519 - Contains hook,dissect,gallbladder
# frame_id VID92_000520 - Contains grasper,retract,gallbladder
# frame_id VID92_000520 - Contains hook,dissect,gallbladder
# frame_id VID92_000521 - Contains grasper,retract,gallbladder
# frame_id VID92_000521 - Contains hook,dissect,gallbladder
# frame_id VID92_000522 - Contains grasper,retract,gallbladder
# frame_id VID92_000522 - Contains hook,dissect,gallbladder
# frame_id VID92_000523 - Contains hook,dissect,gallbladder
# frame_id VID92_000524 - Contains grasper,retract,gallbladder
# frame_id VID92_000524 - Contains hook,dissect,gallbladder
# frame_id VID92_000525 - Contains grasper,retract,gallbladder
# frame_id VID92_000525 - Contains hook,dissect,gallbladder
# frame_id VID92_000525 - Contains hook,dissect,omentum
# frame_id VID92_000526 - Contains grasper,retract,gallbladder
# frame_id VID92_000526 - Contains hook,dissect,gallbladder
# frame_id VID92_000527 - Contains grasper,retract,gallbladder
# frame_id VID92_000528 - Contains grasper,retract,gallbladder
# frame_id VID92_000528 - Contains hook,dissect,gallbladder
# frame_id VID92_000529 - Contains grasper,retract,gallbladder
# frame_id VID92_000529 - Contains hook,dissect,gallbladder
# frame_id VID92_000530 - Contains grasper,retract,gallbladder
# frame_id VID92_000533 - Contains grasper,retract,gallbladder
# frame_id VID92_000533 - Contains hook,dissect,gallbladder
# frame_id VID92_000536 - Contains grasper,retract,gallbladder
# frame_id VID92_000537 - Contains grasper,retract,gallbladder
# frame_id VID92_000538 - Contains grasper,retract,gallbladder
# frame_id VID92_000538 - Contains hook,dissect,gallbladder
# frame_id VID92_000539 - Contains grasper,retract,gallbladder
# frame_id VID92_000539 - Contains hook,dissect,gallbladder
# frame_id VID92_000540 - Contains grasper,retract,gallbladder
# frame_id VID92_000540 - Contains hook,dissect,gallbladder
# frame_id VID92_000541 - Contains hook,dissect,omentum
# frame_id VID92_000542 - Contains hook,dissect,gallbladder
# frame_id VID92_000543 - Contains grasper,retract,gallbladder
# frame_id VID92_000543 - Contains hook,dissect,gallbladder
# frame_id VID92_000544 - Contains grasper,retract,gallbladder
# frame_id VID92_000544 - Contains hook,dissect,gallbladder
# frame_id VID92_000545 - Contains hook,dissect,gallbladder
# frame_id VID92_000546 - Contains hook,dissect,omentum
# frame_id VID92_000547 - Contains hook,dissect,gallbladder
# frame_id VID92_000548 - Contains grasper,retract,gallbladder
# frame_id VID92_000549 - Contains hook,dissect,omentum
# frame_id VID92_000551 - Contains grasper,retract,gallbladder
# frame_id VID92_000551 - Contains grasper,retract,omentum
# frame_id VID92_000551 - Contains hook,dissect,gallbladder
# frame_id VID92_000552 - Contains grasper,retract,gallbladder
# frame_id VID92_000552 - Contains hook,dissect,gallbladder
# frame_id VID92_000554 - Contains grasper,retract,gallbladder
# frame_id VID92_000555 - Contains grasper,retract,gallbladder
# frame_id VID92_000556 - Contains grasper,retract,gallbladder
# frame_id VID92_000556 - Contains hook,dissect,gallbladder
# frame_id VID92_000557 - Contains grasper,retract,gallbladder
# frame_id VID92_000558 - Contains grasper,retract,gallbladder
# frame_id VID92_000558 - Contains grasper,retract,omentum
# frame_id VID92_000559 - Contains grasper,retract,gallbladder
# frame_id VID92_000559 - Contains grasper,retract,omentum
# frame_id VID92_000560 - Contains grasper,retract,gallbladder
# frame_id VID92_000560 - Contains grasper,retract,omentum
# frame_id VID92_000561 - Contains grasper,retract,gallbladder
# frame_id VID92_000562 - Contains grasper,retract,gallbladder
# frame_id VID92_000563 - Contains grasper,retract,gallbladder
# frame_id VID92_000564 - Contains grasper,retract,gallbladder
# frame_id VID92_000565 - Contains grasper,retract,gallbladder
# frame_id VID92_000566 - Contains grasper,retract,gallbladder
# frame_id VID92_000567 - Contains grasper,retract,gallbladder
# frame_id VID92_000569 - Contains grasper,retract,omentum
# frame_id VID92_000570 - Contains grasper,retract,gallbladder
# frame_id VID92_000570 - Contains grasper,retract,omentum
# frame_id VID92_000570 - Contains hook,dissect,gallbladder
# frame_id VID92_000571 - Contains grasper,retract,gallbladder
# frame_id VID92_000572 - Contains hook,dissect,gallbladder
# frame_id VID92_000573 - Contains hook,dissect,omentum
# frame_id VID92_000574 - Contains hook,dissect,gallbladder
# frame_id VID92_000576 - Contains hook,dissect,gallbladder
# frame_id VID92_000577 - Contains hook,dissect,gallbladder
# frame_id VID92_000578 - Contains hook,dissect,gallbladder
# frame_id VID92_000580 - Contains hook,dissect,gallbladder
# frame_id VID92_000581 - Contains hook,dissect,gallbladder
# frame_id VID92_000582 - Contains hook,dissect,gallbladder
# frame_id VID92_000583 - Contains hook,dissect,gallbladder
# frame_id VID92_000585 - Contains hook,dissect,gallbladder
# frame_id VID92_000586 - Contains hook,dissect,gallbladder
# frame_id VID92_000587 - Contains hook,dissect,gallbladder
# frame_id VID92_000588 - Contains hook,dissect,gallbladder
# frame_id VID92_000589 - Contains hook,dissect,gallbladder
# frame_id VID92_000590 - Contains hook,dissect,gallbladder
# frame_id VID92_000591 - Contains hook,dissect,gallbladder
# frame_id VID92_000592 - Contains hook,dissect,gallbladder
# frame_id VID92_000593 - Contains hook,dissect,gallbladder
# frame_id VID92_000594 - Contains hook,dissect,gallbladder
# frame_id VID92_000595 - Contains hook,dissect,gallbladder
# frame_id VID92_000596 - Contains hook,dissect,gallbladder
# frame_id VID92_000597 - Contains hook,dissect,gallbladder
# frame_id VID92_000598 - Contains hook,dissect,gallbladder
# frame_id VID92_000599 - Contains hook,dissect,gallbladder
# frame_id VID92_000600 - Contains hook,dissect,gallbladder
# frame_id VID92_000601 - Contains hook,dissect,cystic_plate
# frame_id VID92_000603 - Contains hook,dissect,gallbladder
# frame_id VID92_000604 - Contains hook,dissect,gallbladder
# frame_id VID92_000605 - Contains hook,dissect,gallbladder
# frame_id VID92_000606 - Contains hook,dissect,gallbladder
# frame_id VID92_000607 - Contains hook,dissect,gallbladder
# frame_id VID92_000608 - Contains hook,dissect,gallbladder
# frame_id VID92_000609 - Contains hook,dissect,gallbladder
# frame_id VID92_000610 - Contains hook,dissect,gallbladder
# frame_id VID92_000611 - Contains hook,dissect,gallbladder
# frame_id VID92_000612 - Contains hook,dissect,gallbladder
# frame_id VID92_000613 - Contains hook,dissect,gallbladder
# frame_id VID92_000614 - Contains hook,dissect,gallbladder
# frame_id VID92_000615 - Contains hook,dissect,gallbladder
# frame_id VID92_000616 - Contains hook,dissect,gallbladder
# frame_id VID92_000617 - Contains hook,dissect,gallbladder
# frame_id VID92_000618 - Contains hook,dissect,gallbladder
# frame_id VID92_000619 - Contains hook,dissect,gallbladder
# frame_id VID92_000620 - Contains hook,dissect,gallbladder
# frame_id VID92_000621 - Contains hook,dissect,gallbladder
# frame_id VID92_000622 - Contains hook,dissect,gallbladder
# frame_id VID92_000623 - Contains hook,dissect,gallbladder
# frame_id VID92_000624 - Contains hook,dissect,gallbladder
# frame_id VID92_000625 - Contains hook,dissect,cystic_duct
# frame_id VID92_000625 - Contains hook,dissect,gallbladder
# frame_id VID92_000626 - Contains hook,dissect,gallbladder
# frame_id VID92_000627 - Contains hook,dissect,gallbladder
# frame_id VID92_000628 - Contains hook,dissect,gallbladder
# frame_id VID92_000630 - Contains hook,dissect,gallbladder
# frame_id VID92_000632 - Contains hook,dissect,gallbladder
# frame_id VID92_000635 - Contains hook,dissect,cystic_duct
# frame_id VID92_000636 - Contains hook,dissect,cystic_duct
# frame_id VID92_000638 - Contains hook,dissect,gallbladder
# frame_id VID92_000639 - Contains hook,dissect,gallbladder
# frame_id VID92_000640 - Contains hook,dissect,gallbladder
# frame_id VID92_000641 - Contains hook,dissect,gallbladder
# frame_id VID92_000642 - Contains hook,dissect,gallbladder
# frame_id VID92_000643 - Contains hook,dissect,gallbladder
# frame_id VID92_000644 - Contains hook,dissect,gallbladder
# frame_id VID92_000655 - Contains grasper,retract,gallbladder
# frame_id VID92_000657 - Contains grasper,retract,gallbladder
# frame_id VID92_000658 - Contains hook,dissect,gallbladder
# frame_id VID92_000660 - Contains grasper,retract,gallbladder
# frame_id VID92_000661 - Contains grasper,retract,gallbladder
# frame_id VID92_000662 - Contains grasper,retract,gallbladder
# frame_id VID92_000665 - Contains grasper,retract,gallbladder
# frame_id VID92_000666 - Contains grasper,retract,gallbladder
# frame_id VID92_000667 - Contains grasper,retract,gallbladder
# frame_id VID92_000668 - Contains grasper,retract,gallbladder
# frame_id VID92_000669 - Contains grasper,retract,gallbladder
# frame_id VID92_000672 - Contains grasper,retract,gallbladder
# frame_id VID92_000674 - Contains grasper,retract,gallbladder
# frame_id VID92_000681 - Contains grasper,retract,gallbladder
# frame_id VID92_000687 - Contains grasper,retract,gallbladder
# frame_id VID92_000688 - Contains grasper,retract,gallbladder
# frame_id VID92_000689 - Contains grasper,retract,gallbladder
# frame_id VID92_000690 - Contains grasper,retract,gallbladder
# frame_id VID92_000691 - Contains grasper,retract,gallbladder
# frame_id VID92_000691 - Contains grasper,null_verb,null_target
# frame_id VID92_000692 - Contains grasper,retract,gallbladder
# frame_id VID92_000693 - Contains grasper,retract,gallbladder
# frame_id VID92_000694 - Contains grasper,retract,gallbladder
# frame_id VID92_000695 - Contains grasper,retract,gallbladder
# frame_id VID92_000695 - Contains grasper,retract,omentum
# frame_id VID92_000696 - Contains grasper,retract,gallbladder
# frame_id VID92_000697 - Contains grasper,retract,gallbladder
# frame_id VID92_000698 - Contains grasper,retract,gallbladder
# frame_id VID92_000699 - Contains grasper,retract,gallbladder
# frame_id VID92_000700 - Contains grasper,retract,gallbladder
# frame_id VID92_000701 - Contains grasper,retract,gallbladder
# frame_id VID92_000701 - Contains grasper,null_verb,null_target
# frame_id VID92_000702 - Contains grasper,retract,gallbladder
# frame_id VID92_000703 - Contains grasper,retract,gallbladder
# frame_id VID92_000703 - Contains grasper,null_verb,null_target
# frame_id VID92_000704 - Contains grasper,retract,gallbladder
# frame_id VID92_000704 - Contains grasper,null_verb,null_target
# frame_id VID92_000705 - Contains grasper,retract,gallbladder
# frame_id VID92_000705 - Contains grasper,null_verb,null_target
# frame_id VID92_000706 - Contains grasper,retract,gallbladder
# frame_id VID92_000707 - Contains grasper,retract,gallbladder
# frame_id VID92_000707 - Contains clipper,null_verb,null_target
# frame_id VID92_000708 - Contains grasper,retract,gallbladder
# frame_id VID92_000708 - Contains clipper,clip,cystic_duct
# frame_id VID92_000709 - Contains grasper,retract,gallbladder
# frame_id VID92_000710 - Contains grasper,retract,gallbladder
# frame_id VID92_000711 - Contains grasper,retract,gallbladder
# frame_id VID92_000712 - Contains grasper,retract,gallbladder
# frame_id VID92_000713 - Contains grasper,retract,gallbladder
# frame_id VID92_000714 - Contains grasper,retract,gallbladder
# ...
# frame_id VID111_001725 - Contains grasper,retract,liver
# frame_id VID111_001725 - Contains bipolar,coagulate,liver
# frame_id VID111_001726 - Contains grasper,retract,liver
# frame_id VID111_001726 - Contains bipolar,coagulate,liver
# frame_id VID111_001727 - Contains grasper,retract,liver
# frame_id VID111_001727 - Contains bipolar,coagulate,liver
# frame_id VID111_001728 - Contains grasper,retract,liver
# frame_id VID111_001728 - Contains bipolar,coagulate,liver
# frame_id VID111_001729 - Contains grasper,retract,liver
# frame_id VID111_001729 - Contains bipolar,coagulate,liver
# frame_id VID111_001730 - Contains grasper,retract,liver
# frame_id VID111_001730 - Contains bipolar,coagulate,liver
# frame_id VID111_001731 - Contains grasper,retract,liver
# frame_id VID111_001731 - Contains bipolar,coagulate,liver
# frame_id VID111_001732 - Contains grasper,retract,liver
# frame_id VID111_001732 - Contains bipolar,coagulate,liver
# frame_id VID111_001733 - Contains grasper,retract,liver
# frame_id VID111_001733 - Contains bipolar,coagulate,liver
# frame_id VID111_001734 - Contains grasper,retract,liver
# frame_id VID111_001734 - Contains bipolar,coagulate,liver
# frame_id VID111_001735 - Contains grasper,retract,liver
# frame_id VID111_001735 - Contains bipolar,coagulate,liver
# frame_id VID111_001736 - Contains grasper,retract,liver
# frame_id VID111_001736 - Contains bipolar,coagulate,liver
# frame_id VID111_001737 - Contains grasper,retract,liver
# frame_id VID111_001737 - Contains bipolar,coagulate,liver
# frame_id VID111_001737 - Contains grasper,null_verb,null_target
# frame_id VID111_001738 - Contains grasper,retract,liver
# frame_id VID111_001738 - Contains bipolar,coagulate,liver
# frame_id VID111_001738 - Contains grasper,null_verb,null_target
# frame_id VID111_001739 - Contains grasper,retract,liver
# frame_id VID111_001739 - Contains bipolar,coagulate,liver
# frame_id VID111_001740 - Contains grasper,retract,liver
# frame_id VID111_001740 - Contains bipolar,coagulate,liver
# frame_id VID111_001741 - Contains grasper,retract,liver
# frame_id VID111_001741 - Contains bipolar,coagulate,liver
# frame_id VID111_001742 - Contains grasper,retract,liver
# frame_id VID111_001742 - Contains bipolar,coagulate,liver
# frame_id VID111_001743 - Contains grasper,retract,liver
# frame_id VID111_001743 - Contains bipolar,coagulate,liver
# frame_id VID111_001744 - Contains grasper,retract,liver
# frame_id VID111_001744 - Contains bipolar,coagulate,liver
# frame_id VID111_001745 - Contains grasper,retract,liver
# frame_id VID111_001745 - Contains bipolar,coagulate,liver
# frame_id VID111_001746 - Contains grasper,retract,liver
# frame_id VID111_001746 - Contains bipolar,coagulate,liver
# frame_id VID111_001747 - Contains grasper,retract,liver
# frame_id VID111_001747 - Contains bipolar,coagulate,liver
# frame_id VID111_001748 - Contains grasper,retract,liver
# frame_id VID111_001748 - Contains bipolar,coagulate,liver
# frame_id VID111_001749 - Contains grasper,retract,liver
# frame_id VID111_001749 - Contains bipolar,coagulate,liver
# frame_id VID111_001750 - Contains grasper,retract,liver
# frame_id VID111_001750 - Contains bipolar,coagulate,liver
# frame_id VID111_001751 - Contains grasper,retract,liver
# frame_id VID111_001751 - Contains bipolar,coagulate,liver
# frame_id VID111_001752 - Contains grasper,retract,liver
# frame_id VID111_001752 - Contains bipolar,coagulate,liver
# frame_id VID111_001753 - Contains grasper,retract,liver
# frame_id VID111_001753 - Contains bipolar,coagulate,liver
# frame_id VID111_001754 - Contains grasper,retract,liver
# frame_id VID111_001754 - Contains bipolar,coagulate,liver
# frame_id VID111_001755 - Contains grasper,retract,liver
# frame_id VID111_001755 - Contains bipolar,coagulate,liver
# frame_id VID111_001756 - Contains grasper,retract,liver
# frame_id VID111_001756 - Contains bipolar,coagulate,liver
# frame_id VID111_001757 - Contains grasper,retract,liver
# frame_id VID111_001757 - Contains bipolar,coagulate,liver
# frame_id VID111_001758 - Contains grasper,retract,liver
# frame_id VID111_001758 - Contains bipolar,coagulate,liver
# frame_id VID111_001759 - Contains grasper,retract,liver
# frame_id VID111_001759 - Contains bipolar,coagulate,liver
# frame_id VID111_001760 - Contains grasper,retract,liver
# frame_id VID111_001760 - Contains bipolar,coagulate,liver
# frame_id VID111_001761 - Contains grasper,retract,liver
# frame_id VID111_001761 - Contains bipolar,coagulate,liver
# frame_id VID111_001762 - Contains grasper,retract,liver
# frame_id VID111_001763 - Contains grasper,retract,liver
# frame_id VID111_001763 - Contains grasper,null_verb,null_target
# frame_id VID111_001764 - Contains grasper,retract,liver
# frame_id VID111_001764 - Contains bipolar,coagulate,liver
# frame_id VID111_001765 - Contains grasper,retract,liver
# frame_id VID111_001765 - Contains bipolar,coagulate,liver
# frame_id VID111_001766 - Contains grasper,retract,liver
# frame_id VID111_001766 - Contains bipolar,coagulate,liver
# frame_id VID111_001767 - Contains grasper,retract,liver
# frame_id VID111_001767 - Contains bipolar,coagulate,liver
# frame_id VID111_001768 - Contains grasper,retract,liver
# frame_id VID111_001769 - Contains grasper,retract,liver
# frame_id VID111_001770 - Contains grasper,retract,liver
# frame_id VID111_001771 - Contains grasper,retract,liver
# frame_id VID111_001772 - Contains grasper,retract,liver
# frame_id VID111_001773 - Contains grasper,retract,gallbladder
# frame_id VID111_001773 - Contains grasper,retract,liver
# frame_id VID111_001774 - Contains grasper,retract,gallbladder
# frame_id VID111_001775 - Contains grasper,retract,gallbladder
# frame_id VID111_001776 - Contains grasper,retract,liver
# frame_id VID111_001780 - Contains grasper,null_verb,null_target
# frame_id VID111_001781 - Contains grasper,retract,liver
# frame_id VID111_001782 - Contains grasper,retract,liver
# frame_id VID111_001783 - Contains grasper,retract,liver
# frame_id VID111_001784 - Contains grasper,retract,liver
# frame_id VID111_001785 - Contains grasper,retract,liver
# frame_id VID111_001786 - Contains grasper,retract,liver
# frame_id VID111_001787 - Contains grasper,retract,liver
# frame_id VID111_001787 - Contains grasper,null_verb,null_target
# frame_id VID111_001788 - Contains grasper,retract,liver
# frame_id VID111_001789 - Contains grasper,retract,liver
# frame_id VID111_001789 - Contains grasper,null_verb,null_target
# frame_id VID111_001790 - Contains grasper,retract,liver
# frame_id VID111_001790 - Contains grasper,null_verb,null_target
# frame_id VID111_001791 - Contains grasper,null_verb,null_target
# frame_id VID111_001792 - Contains grasper,retract,liver
# frame_id VID111_001793 - Contains grasper,retract,liver
# frame_id VID111_001793 - Contains grasper,null_verb,null_target
# frame_id VID111_001794 - Contains grasper,retract,liver
# frame_id VID111_001795 - Contains grasper,retract,liver
# frame_id VID111_001796 - Contains grasper,retract,liver
# frame_id VID111_001797 - Contains grasper,retract,liver
# frame_id VID111_001798 - Contains grasper,retract,liver
# frame_id VID111_001799 - Contains grasper,retract,liver
# frame_id VID111_001800 - Contains grasper,retract,liver
# frame_id VID111_001801 - Contains grasper,retract,liver
# frame_id VID111_001801 - Contains grasper,null_verb,null_target
# frame_id VID111_001803 - Contains grasper,retract,liver
# frame_id VID111_001803 - Contains grasper,null_verb,null_target
# frame_id VID111_001804 - Contains grasper,retract,liver
# frame_id VID111_001805 - Contains grasper,retract,liver
# frame_id VID111_001806 - Contains grasper,retract,liver
# frame_id VID111_001807 - Contains grasper,retract,liver
# frame_id VID111_001807 - Contains hook,dissect,gallbladder
# frame_id VID111_001808 - Contains grasper,retract,liver
# frame_id VID111_001809 - Contains grasper,retract,liver
# frame_id VID111_001810 - Contains grasper,retract,liver
# frame_id VID111_001812 - Contains grasper,retract,liver
# frame_id VID111_001813 - Contains grasper,retract,liver
# frame_id VID111_001814 - Contains grasper,retract,liver
# frame_id VID111_001815 - Contains grasper,null_verb,null_target
# frame_id VID111_001816 - Contains grasper,retract,liver
# frame_id VID111_001816 - Contains grasper,null_verb,null_target
# frame_id VID111_001842 - Contains grasper,retract,liver
# frame_id VID111_001843 - Contains grasper,retract,liver
# frame_id VID111_001844 - Contains grasper,retract,liver
# frame_id VID111_001845 - Contains grasper,retract,liver
# frame_id VID111_001846 - Contains grasper,retract,liver
# frame_id VID111_001847 - Contains grasper,retract,liver
# frame_id VID111_001848 - Contains grasper,retract,liver
# frame_id VID111_001849 - Contains grasper,retract,liver
# frame_id VID111_001850 - Contains grasper,retract,liver
# frame_id VID111_001851 - Contains grasper,retract,liver
# frame_id VID111_001854 - Contains grasper,retract,liver
# frame_id VID111_001855 - Contains grasper,retract,liver
# frame_id VID111_001856 - Contains grasper,retract,liver
# frame_id VID111_001857 - Contains grasper,retract,liver
# frame_id VID111_001858 - Contains grasper,retract,liver
# frame_id VID111_001859 - Contains grasper,retract,liver
# frame_id VID111_001860 - Contains grasper,retract,liver
# frame_id VID111_001861 - Contains grasper,retract,liver
# frame_id VID111_001862 - Contains grasper,retract,liver
# frame_id VID111_001863 - Contains grasper,retract,liver
# frame_id VID111_001864 - Contains grasper,retract,liver
# frame_id VID111_001864 - Contains grasper,null_verb,null_target
# frame_id VID111_001865 - Contains grasper,retract,liver
# frame_id VID111_001865 - Contains grasper,null_verb,null_target
# frame_id VID111_001866 - Contains grasper,retract,liver
# frame_id VID111_001867 - Contains grasper,retract,liver
# frame_id VID111_001867 - Contains grasper,null_verb,null_target
# frame_id VID111_001868 - Contains grasper,null_verb,null_target
# frame_id VID111_001871 - Contains grasper,retract,liver
# frame_id VID111_001871 - Contains grasper,null_verb,null_target
# frame_id VID111_001872 - Contains grasper,null_verb,null_target
# frame_id VID111_001873 - Contains grasper,null_verb,null_target
# frame_id VID111_001874 - Contains grasper,null_verb,null_target
# frame_id VID111_001875 - Contains grasper,null_verb,null_target
# frame_id VID111_001876 - Contains grasper,null_verb,null_target
# frame_id VID111_001877 - Contains grasper,null_verb,null_target
# frame_id VID111_001878 - Contains grasper,null_verb,null_target
# frame_id VID111_001879 - Contains grasper,retract,liver
# frame_id VID111_001880 - Contains grasper,retract,liver
# frame_id VID111_001880 - Contains grasper,null_verb,null_target
# frame_id VID111_001881 - Contains grasper,null_verb,null_target
# frame_id VID111_001882 - Contains grasper,retract,liver
# frame_id VID111_001882 - Contains grasper,null_verb,null_target
# frame_id VID111_001883 - Contains grasper,retract,liver
# frame_id VID111_001885 - Contains grasper,retract,liver
# frame_id VID111_001886 - Contains grasper,null_verb,null_target
# frame_id VID111_001888 - Contains grasper,retract,liver
# frame_id VID111_001888 - Contains bipolar,coagulate,liver
# frame_id VID111_001889 - Contains bipolar,coagulate,liver
# frame_id VID111_001889 - Contains grasper,null_verb,null_target
# frame_id VID111_001890 - Contains grasper,retract,liver
# frame_id VID111_001892 - Contains grasper,retract,liver
# frame_id VID111_001892 - Contains bipolar,coagulate,liver
# frame_id VID111_001893 - Contains grasper,retract,liver
# frame_id VID111_001893 - Contains bipolar,coagulate,liver
# frame_id VID111_001895 - Contains grasper,retract,liver
# frame_id VID111_001897 - Contains grasper,retract,liver
# frame_id VID111_001897 - Contains bipolar,coagulate,gallbladder
# frame_id VID111_001898 - Contains grasper,retract,liver
# frame_id VID111_001899 - Contains grasper,retract,liver
# frame_id VID111_001899 - Contains bipolar,coagulate,liver
# frame_id VID111_001900 - Contains grasper,retract,liver
# frame_id VID111_001901 - Contains grasper,retract,liver
# frame_id VID111_001902 - Contains grasper,retract,liver
# frame_id VID111_001903 - Contains grasper,retract,liver
# frame_id VID111_001904 - Contains grasper,retract,liver
# frame_id VID111_001905 - Contains grasper,retract,liver
# frame_id VID111_001905 - Contains grasper,null_verb,null_target
# frame_id VID111_001906 - Contains grasper,retract,liver
# frame_id VID111_001907 - Contains grasper,retract,liver
# frame_id VID111_001939 - Contains grasper,null_verb,null_target
# frame_id VID111_001940 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001941 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001942 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001943 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001943 - Contains grasper,null_verb,null_target
# frame_id VID111_001944 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001944 - Contains grasper,null_verb,null_target
# frame_id VID111_001945 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001945 - Contains grasper,null_verb,null_target
# frame_id VID111_001946 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001946 - Contains grasper,null_verb,null_target
# frame_id VID111_001947 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001947 - Contains grasper,null_verb,null_target
# frame_id VID111_001948 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001949 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001952 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001953 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001954 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001955 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001959 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001960 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001960 - Contains grasper,null_verb,null_target
# frame_id VID111_001961 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001962 - Contains grasper,null_verb,null_target
# frame_id VID111_001963 - Contains grasper,null_verb,null_target
# frame_id VID111_001964 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001965 - Contains grasper,retract,liver
# frame_id VID111_001966 - Contains grasper,retract,liver
# frame_id VID111_001970 - Contains grasper,null_verb,null_target
# frame_id VID111_001971 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001971 - Contains grasper,null_verb,null_target
# frame_id VID111_001972 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001972 - Contains grasper,null_verb,null_target
# frame_id VID111_001974 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001978 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001978 - Contains grasper,null_verb,null_target
# frame_id VID111_001979 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001980 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001981 - Contains grasper,null_verb,null_target
# frame_id VID111_001981 - Contains bipolar,null_verb,null_target
# frame_id VID111_001982 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001991 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001992 - Contains grasper,grasp,specimen_bag
# frame_id VID111_001994 - Contains grasper,retract,gallbladder
# frame_id VID111_001997 - Contains bipolar,coagulate,abdominal_wall_cavity
# frame_id VID111_002000 - Contains bipolar,coagulate,abdominal_wall_cavity
# frame_id VID111_002001 - Contains bipolar,coagulate,abdominal_wall_cavity
# frame_id VID111_002002 - Contains bipolar,coagulate,abdominal_wall_cavity
# frame_id VID111_002003 - Contains bipolar,coagulate,abdominal_wall_cavity
# frame_id VID111_002004 - Contains bipolar,coagulate,abdominal_wall_cavity
# frame_id VID111_002009 - Contains bipolar,coagulate,abdominal_wall_cavity
# frame_id VID111_002010 - Contains bipolar,coagulate,abdominal_wall_cavity
# frame_id VID111_002014 - Contains grasper,grasp,specimen_bag
# frame_id VID111_002015 - Contains grasper,grasp,specimen_bag
# frame_id VID111_002021 - Contains grasper,grasp,specimen_bag
# frame_id VID111_002023 - Contains grasper,grasp,specimen_bag
# frame_id VID111_002024 - Contains grasper,grasp,specimen_bag
# frame_id VID111_002025 - Contains grasper,grasp,specimen_bag
# frame_id VID111_002026 - Contains grasper,grasp,specimen_bag
# frame_id VID111_002027 - Contains grasper,grasp,specimen_bag

# %%
print("Predicted Triplet Counts:", predicted_counts)
print("Missing Triplets:", missing_predicted_triplets)
# Out:
# Predicted Triplet Counts: {'grasper,grasp,specimen_bag': 588, 'grasper,null_verb,null_target': 638, 'grasper,retract,gallbladder': 3118, 'grasper,retract,omentum': 282, 'grasper,grasp,gallbladder': 126, 'hook,dissect,omentum': 221, 'hook,dissect,gallbladder': 3666, 'hook,dissect,cystic_duct': 152, 'hook,dissect,cystic_plate': 77, 'clipper,null_verb,null_target': 6, 'clipper,clip,cystic_duct': 121, 'scissors,cut,cystic_duct': 47, 'grasper,retract,liver': 1391, 'bipolar,coagulate,liver': 387, 'bipolar,coagulate,cystic_plate': 12, 'bipolar,coagulate,gallbladder': 24, 'grasper,pack,gallbladder': 2, 'bipolar,null_verb,null_target': 13, 'bipolar,dissect,gallbladder': 3, 'bipolar,coagulate,abdominal_wall_cavity': 20, 'grasper,retract,gut': 11, 'hook,null_verb,null_target': 75, 'hook,dissect,cystic_artery': 16, 'bipolar,dissect,cystic_duct': 1, 'clipper,clip,cystic_artery': 28, 'grasper,dissect,gallbladder': 2, 'grasper,retract,cystic_plate': 3, 'irrigator,aspirate,fluid': 7, 'scissors,cut,cystic_artery': 3, 'scissors,dissect,gallbladder': 5, 'scissors,null_verb,null_target': 1, 'grasper,retract,peritoneum': 1, 'hook,coagulate,gallbladder': 1, 'hook,coagulate,liver': 7, 'irrigator,null_verb,null_target': 1}
# Missing Triplets: ['bipolar,coagulate,blood_vessel', 'bipolar,coagulate,cystic_artery', 'bipolar,coagulate,cystic_duct', 'bipolar,coagulate,cystic_pedicle', 'bipolar,coagulate,omentum', 'bipolar,coagulate,peritoneum', 'bipolar,dissect,adhesion', 'bipolar,dissect,cystic_artery', 'bipolar,dissect,cystic_plate', 'bipolar,dissect,omentum', 'bipolar,grasp,cystic_plate', 'bipolar,grasp,liver', 'bipolar,grasp,specimen_bag', 'bipolar,retract,cystic_duct', 'bipolar,retract,cystic_pedicle', 'bipolar,retract,gallbladder', 'bipolar,retract,liver', 'bipolar,retract,omentum', 'clipper,clip,blood_vessel', 'clipper,clip,cystic_pedicle', 'clipper,clip,cystic_plate', 'grasper,dissect,cystic_plate', 'grasper,dissect,omentum', 'grasper,grasp,cystic_artery', 'grasper,grasp,cystic_duct', 'grasper,grasp,cystic_pedicle', 'grasper,grasp,cystic_plate', 'grasper,grasp,gut', 'grasper,grasp,liver', 'grasper,grasp,omentum', 'grasper,grasp,peritoneum', 'grasper,retract,cystic_duct', 'grasper,retract,cystic_pedicle', 'hook,coagulate,blood_vessel', 'hook,coagulate,cystic_artery', 'hook,coagulate,cystic_duct', 'hook,coagulate,cystic_pedicle', 'hook,coagulate,cystic_plate', 'hook,coagulate,omentum', 'hook,cut,blood_vessel', 'hook,cut,peritoneum', 'hook,dissect,blood_vessel', 'hook,dissect,peritoneum', 'hook,retract,gallbladder', 'hook,retract,liver', 'irrigator,dissect,cystic_duct', 'irrigator,dissect,cystic_pedicle', 'irrigator,dissect,cystic_plate', 'irrigator,dissect,gallbladder', 'irrigator,dissect,omentum', 'irrigator,irrigate,abdominal_wall_cavity', 'irrigator,irrigate,cystic_pedicle', 'irrigator,irrigate,liver', 'irrigator,retract,gallbladder', 'irrigator,retract,liver', 'irrigator,retract,omentum', 'scissors,coagulate,omentum', 'scissors,cut,adhesion', 'scissors,cut,blood_vessel', 'scissors,cut,cystic_plate', 'scissors,cut,liver', 'scissors,cut,omentum', 'scissors,cut,peritoneum', 'scissors,dissect,cystic_plate', 'scissors,dissect,omentum']

# %%
print(len(missing_predicted_triplets))
print(len(predicted_counts))
# Out:
# 65
# 35

# %%
nan_indices = np.where(np.isnan(results_cholecT50_chal))[0]  # [0] extracts the indices from the tuple

print("Indices of NaNs:", nan_indices)
print(len(nan_indices))
# Out:
# Indices of NaNs: [ 0  1  2  3  6 14 15 16 20 21 24 25 26 27 28 30 32 35 37 38 39 41 42 43
#  44 45 47 49 50 51 53 56 59 61 64 65 66 67 70 71 73 74 75 76 80 81 83 84
#  85 86 87 89 91 92 93]
# 55

# %%
predicted_triplet_ids = sorted([int(triplet_id)-1 for triplet_id, name in triplet_mapping.items() if name in predicted_counts.keys()])

# %%
len(predicted_triplet_ids)
# Out:
# 35

# %%
predicted_set = set(predicted_triplet_ids)
nan_set = set(nan_indices)

nans_that_were_predicted = predicted_set & nan_set  # In predicted and nans
nans_that_were_predicted
# Out:
# {1, 16, 20, 21, 27, 28, 51, 59, 61, 75}

# %%
for pred_id in nans_that_were_predicted:
    pred_name = triplet_mapping[str(pred_id+1)]
    print(f'pred_id {pred_id} {pred_name} {predicted_counts[pred_name]}')
    print(results_cholecT50_chal[pred_id])
# Out:
# pred_id 1 grasper,dissect,gallbladder 2
# nan
# pred_id 59 hook,dissect,cystic_plate 77
# nan
# pred_id 75 scissors,dissect,gallbladder 5
# nan
# pred_id 16 grasper,retract,cystic_plate 3
# nan
# pred_id 51 hook,coagulate,gallbladder 1
# nan
# pred_id 20 grasper,retract,omentum 282
# nan
# pred_id 21 grasper,retract,peritoneum 1
# nan
# pred_id 27 bipolar,coagulate,cystic_plate 12
# nan
# pred_id 28 bipolar,coagulate,gallbladder 24
# nan
# pred_id 61 hook,dissect,omentum 221
# nan

# %% [markdown]
# There are 10 classes which have predictions but no ground truth and it is reported as NaN which is wrong.

# %% [markdown]
# ### 2. When there is 0 prediction and there exists ground_truth, this should also be zero

# %% [markdown]
# for this one, we need to check all the places that have missing predictions and see if it aligns with ground_truth that exists. It should give zero
#
# There are 35 predictions but there 45 ground_truths, hence there must at least be 10 that have zero in ivt but looking at it, there are no zeros, something is wrong here.

# %%
np.array(results_cholecT50_chal) == 0
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %% [markdown]
# There is none that is zero so something is fishy here.

# %%
predicted_set = set(predicted_triplet_ids)

gt_triplet_ids = sorted([int(triplet_id)-1 for triplet_id, name in triplet_mapping.items() if name in triplet_counts.keys()])
gt_set = set(gt_triplet_ids)

# %%
extra_in_predicted = predicted_set - gt_set  #if there is even any extra
extra_in_gt = gt_set - predicted_set  # I expect at least ten, it could be more. 

if not extra_in_predicted and not extra_in_gt:
    print("The lists contain the same elements.")
else:
    print("Differences found!")
    if extra_in_predicted:
        print("Extra elements in predicted indices:", extra_in_predicted)
    if extra_in_gt:
        print("Extra elements in gt_indices:", extra_in_gt)
# Out:
# Differences found!
# Extra elements in predicted indices: {1, 59, 75, 16, 51, 20, 21, 27, 28, 61}
# Extra elements in gt_indices: {4, 5, 8, 9, 10, 11, 23, 31, 33, 40, 46, 48, 54, 55, 62, 63, 72, 77, 88, 90}

# %%
print(extra_in_predicted)
print(nans_that_were_predicted)
# Out:
# {1, 59, 75, 16, 51, 20, 21, 27, 28, 61}
# {1, 59, 75, 16, 51, 20, 21, 27, 28, 61}

# %% [markdown]
# That makes sense, these things that we have predictions for , but no groundtruth, they were teh nans that have predictions.

# %% [markdown]
# This then implies that there are another 20 which should have been zeros that were not zeros. They are the groundtruths that have no predictions, but somehow are not scored as zeros

# %%
for gt_id_that_should_be_zero in extra_in_gt:
    gt_name = triplet_mapping[str(gt_id_that_should_be_zero+1)]
    print(f'gt_id_that_should_be_zero {gt_id_that_should_be_zero} {gt_name}')
    print(f'frequency in gt {triplet_counts[gt_name]}')
    print(f'frequency in pred {predicted_counts.get(gt_name, 0)}')
    print(f'is it in missing from pred {gt_name in missing_predicted_triplets}')
    print('result on old ivtmetrics' , results_cholecT50_chal[gt_id_that_should_be_zero]) 
    print('=================================================')
# Out:
# gt_id_that_should_be_zero 4 grasper,grasp,cystic_duct
# frequency in gt 174
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.14238042
# =================================================
# gt_id_that_should_be_zero 5 grasper,grasp,cystic_pedicle
# frequency in gt 1
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.000512557663
# =================================================
# gt_id_that_should_be_zero 8 grasper,grasp,gut
# frequency in gt 24
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.0194041245
# =================================================
# gt_id_that_should_be_zero 9 grasper,grasp,liver
# frequency in gt 16
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.00441499286
# =================================================
# gt_id_that_should_be_zero 10 grasper,grasp,omentum
# frequency in gt 6
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.0151810978
# =================================================
# gt_id_that_should_be_zero 11 grasper,grasp,peritoneum
# frequency in gt 324
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.105866348
# =================================================
# gt_id_that_should_be_zero 23 bipolar,coagulate,blood_vessel
# frequency in gt 74
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.382526038
# =================================================
# gt_id_that_should_be_zero 31 bipolar,coagulate,peritoneum
# frequency in gt 12
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.681760326
# =================================================
# gt_id_that_should_be_zero 33 bipolar,dissect,cystic_artery
# frequency in gt 82
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.239063315
# =================================================
# gt_id_that_should_be_zero 40 bipolar,grasp,specimen_bag
# frequency in gt 3
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.0224427652
# =================================================
# gt_id_that_should_be_zero 46 hook,coagulate,blood_vessel
# frequency in gt 35
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.00529207639
# =================================================
# gt_id_that_should_be_zero 48 hook,coagulate,cystic_duct
# frequency in gt 1
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.00628930818
# =================================================
# gt_id_that_should_be_zero 54 hook,cut,blood_vessel
# frequency in gt 13
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.00413746771
# =================================================
# gt_id_that_should_be_zero 55 hook,cut,peritoneum
# frequency in gt 92
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.0578127295
# =================================================
# gt_id_that_should_be_zero 62 hook,dissect,peritoneum
# frequency in gt 54
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.0574473847
# =================================================
# gt_id_that_should_be_zero 63 hook,retract,gallbladder
# frequency in gt 4
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.00100791122
# =================================================
# gt_id_that_should_be_zero 72 scissors,cut,omentum
# frequency in gt 3
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.206043956
# =================================================
# gt_id_that_should_be_zero 77 clipper,clip,blood_vessel
# frequency in gt 14
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.103012725
# =================================================
# gt_id_that_should_be_zero 88 irrigator,irrigate,abdominal_wall_cavity
# frequency in gt 1
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.00420168067
# =================================================
# gt_id_that_should_be_zero 90 irrigator,irrigate,liver
# frequency in gt 3
# frequency in pred 0
# is it in missing from pred True
# result on old ivtmetrics 0.0105711606
# =================================================

# %% [markdown]
# They are essentially passing the whole triplet vector in, so they are not doing what we are doing, but they are passing all the triplet classes in!!! That is why we have predictions even when things are missing.
#
# But there should be a threshold, there should be a threshold, even when working with logits.

# %% [markdown]
# Questions to answer?
#
# Why does the new version not have any NaN at all? Their method for catching when it is NaN is wrong, likely the output from sklearn is no longer

# %%
from sklearn.metrics import average_precision_score

# Example true labels
y_true = [0, 0, 1, 1]


# Probabilities (e.g., logistic regression)
y_scores_proba = [0.1, 0.2, 0.3, 0.9]  # Probabilities of class 1

# Compute Average Precision Score
ap_proba = average_precision_score(y_true, y_scores_proba)

print("AP Score using probabilities:", ap_proba)
# Out:
# AP Score using probabilities: 1.0

# %% [markdown]
# It does not use threshold of 0.5, that is why I am making mistakes
#
# So my whole analysis is wrong.
#
# As classification AP is not the same as Detection AP, very different in their calculations

# %% [markdown]
# My analysis is very wrong and i realize I have being looking at things from the view of object detection

# %% [markdown]
# The same analysis is required in the detection one.

# %% [markdown]
# Under detection rules, what would be the triplet score?

# %%
results_cholecT50_chal_copy = results_cholecT50_chal[:]

# %%
results_cholecT50_chal_copy = np.array(results_cholecT50_chal_copy)
results_cholecT50_chal_copy
# Out:
# array([           nan,            nan,            nan,            nan,
#        1.42380420e-01, 5.12557663e-04,            nan, 3.32626728e-01,
#        1.94041245e-02, 4.41499286e-03, 1.51810978e-02, 1.05866348e-01,
#        7.66676512e-01, 3.34643930e-01,            nan,            nan,
#                   nan, 3.49844877e-01, 2.36705437e-01, 6.40751279e-01,
#                   nan,            nan, 6.16255123e-01, 3.82526038e-01,
#                   nan,            nan,            nan,            nan,
#                   nan, 9.38378809e-01,            nan, 6.81760326e-01,
#                   nan, 2.39063315e-01, 6.76337083e-01,            nan,
#        1.46892996e-01,            nan,            nan,            nan,
#        2.24427652e-02,            nan,            nan,            nan,
#                   nan,            nan, 5.29207639e-03,            nan,
#        6.28930818e-03,            nan,            nan,            nan,
#        8.23852417e-04,            nan, 4.13746771e-03, 5.78127295e-02,
#                   nan, 9.06361298e-02, 5.12866891e-01,            nan,
#        7.72888383e-01,            nan, 5.74473847e-02, 1.00791122e-03,
#                   nan,            nan,            nan,            nan,
#        5.51408207e-01, 7.13270129e-01,            nan,            nan,
#        2.06043956e-01,            nan,            nan,            nan,
#                   nan, 1.03012725e-01, 7.70445042e-01, 6.79152307e-01,
#                   nan,            nan, 7.19090642e-02,            nan,
#                   nan,            nan,            nan,            nan,
#        4.20168067e-03,            nan, 1.05711606e-02,            nan,
#                   nan,            nan])

# %% [markdown]
# extra_in_predicted refer to the ground_truths that do not exist but have predictions, the score should be zero

# %%
results_cholecT50_chal_copy[list(extra_in_predicted)] = 0
results_cholecT50_chal_copy
# Out:
# array([           nan, 0.00000000e+00,            nan,            nan,
#        1.42380420e-01, 5.12557663e-04,            nan, 3.32626728e-01,
#        1.94041245e-02, 4.41499286e-03, 1.51810978e-02, 1.05866348e-01,
#        7.66676512e-01, 3.34643930e-01,            nan,            nan,
#        0.00000000e+00, 3.49844877e-01, 2.36705437e-01, 6.40751279e-01,
#        0.00000000e+00, 0.00000000e+00, 6.16255123e-01, 3.82526038e-01,
#                   nan,            nan,            nan, 0.00000000e+00,
#        0.00000000e+00, 9.38378809e-01,            nan, 6.81760326e-01,
#                   nan, 2.39063315e-01, 6.76337083e-01,            nan,
#        1.46892996e-01,            nan,            nan,            nan,
#        2.24427652e-02,            nan,            nan,            nan,
#                   nan,            nan, 5.29207639e-03,            nan,
#        6.28930818e-03,            nan,            nan, 0.00000000e+00,
#        8.23852417e-04,            nan, 4.13746771e-03, 5.78127295e-02,
#                   nan, 9.06361298e-02, 5.12866891e-01, 0.00000000e+00,
#        7.72888383e-01, 0.00000000e+00, 5.74473847e-02, 1.00791122e-03,
#                   nan,            nan,            nan,            nan,
#        5.51408207e-01, 7.13270129e-01,            nan,            nan,
#        2.06043956e-01,            nan,            nan, 0.00000000e+00,
#                   nan, 1.03012725e-01, 7.70445042e-01, 6.79152307e-01,
#                   nan,            nan, 7.19090642e-02,            nan,
#                   nan,            nan,            nan,            nan,
#        4.20168067e-03,            nan, 1.05711606e-02,            nan,
#                   nan,            nan])

# %% [markdown]
# extra in gt refers to pred that do not exist but there are groudtruths present, all missing false negatives

# %%
results_cholecT50_chal_copy[list(extra_in_gt)] = 0
results_cholecT50_chal_copy
# Out:
# array([           nan, 0.00000000e+00,            nan,            nan,
#        0.00000000e+00, 0.00000000e+00,            nan, 3.32626728e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.66676512e-01, 3.34643930e-01,            nan,            nan,
#        0.00000000e+00, 3.49844877e-01, 2.36705437e-01, 6.40751279e-01,
#        0.00000000e+00, 0.00000000e+00, 6.16255123e-01, 0.00000000e+00,
#                   nan,            nan,            nan, 0.00000000e+00,
#        0.00000000e+00, 9.38378809e-01,            nan, 0.00000000e+00,
#                   nan, 0.00000000e+00, 6.76337083e-01,            nan,
#        1.46892996e-01,            nan,            nan,            nan,
#        0.00000000e+00,            nan,            nan,            nan,
#                   nan,            nan, 0.00000000e+00,            nan,
#        0.00000000e+00,            nan,            nan, 0.00000000e+00,
#        8.23852417e-04,            nan, 0.00000000e+00, 0.00000000e+00,
#                   nan, 9.06361298e-02, 5.12866891e-01, 0.00000000e+00,
#        7.72888383e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#                   nan,            nan,            nan,            nan,
#        5.51408207e-01, 7.13270129e-01,            nan,            nan,
#        0.00000000e+00,            nan,            nan, 0.00000000e+00,
#                   nan, 0.00000000e+00, 7.70445042e-01, 6.79152307e-01,
#                   nan,            nan, 7.19090642e-02,            nan,
#                   nan,            nan,            nan,            nan,
#        0.00000000e+00,            nan, 0.00000000e+00,            nan,
#                   nan,            nan])

# %%
np.nanmean(results_cholecT50_chal_copy)
# Out:
# 0.18780638325340818

# %% [markdown]
# Well this is not actually correct as well, the values of the AP the plotting is different. But it is getting closer
