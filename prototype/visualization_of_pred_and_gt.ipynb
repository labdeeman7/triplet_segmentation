# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')

# %% [markdown]
# ## Visualize the predictions

# %%
from utils.visualization.vis_utils import VisFromLabelMeToImg

# %%
experiment_name = 'threetask_resnet_fpn_parallel_decoders'
img_dir = "../data/triplet_segmentation_dataset_v2_second_stage/mask2former_instrument_prediction/img_dir"
pred_ann_dir = f'../resnet_model/work_dirs/{experiment_name}/combine_first_and_second_stage_results' 
pred_store_vis_dir = f'../resnet_model/work_dirs/{experiment_name}/vis_dir_pred'


vis_for_reannotation_generator = VisFromLabelMeToImg(img_dir=img_dir,
                                                    ann_dir=pred_ann_dir,
                                                    vis_dir=pred_store_vis_dir)

# %%
vis_for_reannotation_generator.run(make_video=False,
                                   show_img_name=False,
                                   vid_shape = (854, 480))

# %% [markdown]
# ## Visualize the GT

# %%
experiment_name = 'threetask_resnet_fpn_parallel_decoders'
img_dir = "../data/triplet_segmentation_dataset_v2_second_stage/mask2former_instrument_prediction/img_dir"
gt_ann_dir = "../data/triplet_segmentation_dataset_v2_second_stage/test/ann_dir"
gt_store_vis_dir = f'../resnet_model/work_dirs/{experiment_name}/vis_gt'


vis_for_reannotation_generator = VisFromLabelMeToImg(img_dir=img_dir,
                                                    ann_dir=gt_ann_dir,
                                                    vis_dir=gt_store_vis_dir)

# %%
vis_for_reannotation_generator.run(make_video=False,
                                   show_img_name=False,
                                   vid_shape = (854, 480))

# %% [markdown]
# ### Combine the folders

# %%
import os
from PIL import Image, ImageDraw, ImageFont

def combine_images(pred_vis_dir, gt_dir, output_dir, header_height=40, font_size=30):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # List of files assuming all directories have the same filenames
    filenames = os.listdir(pred_vis_dir)
    
    # Set font for headers
    try:
        font = ImageFont.truetype("arial.ttf", font_size)
    except IOError:
        font = ImageFont.load_default()
    
    for filename in filenames:
        # Load images
        pred_img = Image.open(os.path.join(pred_vis_dir, filename))
        gt_img = Image.open(os.path.join(gt_dir, filename))
        
        # Determine dimensions
        width, height = pred_img.size
        total_width = width * 2
        total_height = height + header_height
        
        # Create a new blank image
        combined_img = Image.new('RGB', (total_width, total_height), (255, 255, 255))
        draw = ImageDraw.Draw(combined_img)
        
        # Add headers
        draw.rectangle([0, 0, width, header_height], fill=(255, 255, 255))
        draw.rectangle([width, 0, width * 2, header_height], fill=(255, 255, 255))
        
        # Calculate text positions
        pred_text_box = draw.textbbox((0, 0), "Pred", font=font)
        maskrcnn_text_width = pred_text_box[2] - pred_text_box[0]
        maskrcnn_text_height = pred_text_box[3] - pred_text_box[1]
        
        
        gt_text_bbox = draw.textbbox((0, 0), "Ground Truth", font=font)
        gt_text_width = gt_text_bbox[2] - gt_text_bbox[0]
        gt_text_height = gt_text_bbox[3] - gt_text_bbox[1]
        
        # Draw headers
        draw.text((width // 2 - maskrcnn_text_width // 2, header_height // 2 - maskrcnn_text_height // 2),
                  "Pred", font=font, fill=(0, 0, 0))
        draw.text((width + width // 2 - gt_text_width // 2, header_height // 2 - gt_text_height // 2),
                  "Ground Truth", font=font, fill=(0, 0, 0))
        
        
        # Paste images below headers
        combined_img.paste(pred_img, (0, header_height))
        combined_img.paste(gt_img, (width, header_height))
        
        # Save the combined image
        combined_img.save(os.path.join(output_dir, filename))

# %%
# Example usage
experiment_name = 'threetask_resnet_fpn_parallel_decoders'
combined_store_vis_dir = f'../resnet_model/work_dirs/{experiment_name}/combined'

combine_images(pred_store_vis_dir, gt_store_vis_dir, combined_store_vis_dir)

# %% [markdown]
# ## Make the videos

# %%
from utils.visualization.video_utils import visualize_as_videos
from os.path import join

# %%
parent_dir = os.path.dirname(combined_store_vis_dir)
video_output_path =  join(parent_dir, 'combined_video.mp4') 
vid_shape = (1708, 520)

# %%
visualize_as_videos(img_dir=combined_store_vis_dir, 
                    video_output_path=video_output_path, 
                    vid_shape=vid_shape,
                    video_fps=4)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1708, 520) to (1712, 528) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000000.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000001.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000002.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000003.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000004.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000005.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000006.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000007.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000008.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000009.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000010.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000012.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000013.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000014.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000015.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000016.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000017.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000018.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000019.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000020.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000021.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000022.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000023.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000024.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000025.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000026.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000119.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000120.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000121.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000122.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000123.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000127.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000128.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000129.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000130.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000131.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000132.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000133.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000134.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000135.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000136.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000137.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000138.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000139.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000140.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000141.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000142.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000143.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000144.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000145.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000146.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000147.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000148.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000149.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000150.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000151.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000152.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000153.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000154.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000155.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000156.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000157.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000158.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000159.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000160.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000161.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000162.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000163.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000164.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000165.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000166.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000167.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000168.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000169.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000170.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000171.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000172.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000173.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000174.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000175.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000176.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000177.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000178.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000179.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000180.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000181.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000182.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000183.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000184.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000185.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000186.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000187.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000188.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000189.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000190.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000191.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000192.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000193.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000194.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000195.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000197.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000198.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000200.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000201.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000204.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000205.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000207.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000208.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000209.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000210.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000211.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000212.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000213.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000214.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000215.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000216.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000217.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000218.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000219.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000220.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000221.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000222.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000223.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000224.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000225.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000226.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000227.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000228.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000229.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000230.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000231.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000232.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000234.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000235.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000236.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000237.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000238.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000239.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000240.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000241.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000242.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000243.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000245.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000246.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000247.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000248.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000249.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000250.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000251.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000252.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000253.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000254.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000255.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000256.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000257.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000258.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000259.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000260.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000261.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000262.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000265.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000266.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000267.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000268.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000269.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000270.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000271.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000272.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000273.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000274.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000275.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000276.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000277.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000278.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000279.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000280.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000281.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000282.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000283.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000284.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000285.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000286.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000287.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000288.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000289.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000290.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000291.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000292.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000293.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000294.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000295.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000296.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000297.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000298.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000299.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000300.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000301.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000302.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000305.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000306.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000307.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000308.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000309.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000310.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000311.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000312.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000313.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000314.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000316.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000317.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000318.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000319.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000320.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000321.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000322.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000323.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000324.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000325.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000327.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000328.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000329.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000330.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000331.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000332.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000333.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000334.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000335.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000336.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000337.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000338.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000339.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000340.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000341.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000342.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000343.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000344.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000345.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000346.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000347.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000348.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000349.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000350.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000351.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000352.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000353.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000355.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000356.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000357.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000358.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000360.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000361.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000362.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000363.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000364.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000365.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000366.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000367.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000368.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000369.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000370.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000372.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000373.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000374.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000375.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000376.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000377.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000378.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000379.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000380.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000381.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000382.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000383.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000384.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000385.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000386.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000387.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000388.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000389.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000390.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000391.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000392.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000393.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000394.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000395.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000396.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000397.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000398.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000399.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000400.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000401.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000402.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000403.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000404.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000405.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000406.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000407.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000408.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000409.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000410.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000411.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000412.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000413.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000414.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000415.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000416.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000417.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000418.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000419.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000420.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000421.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000422.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000423.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000424.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000425.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000427.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000428.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000429.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000430.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000431.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000432.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000433.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000434.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000435.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000436.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000437.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000438.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000439.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000440.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000441.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000442.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000443.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000444.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000445.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000446.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000447.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000448.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000450.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000452.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000453.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000454.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000455.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000457.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000460.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000461.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000462.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000463.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000464.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000465.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000466.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000467.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000468.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000469.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000470.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000471.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000472.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000473.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000474.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000475.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000476.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000477.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000478.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000479.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000480.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000481.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000482.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000483.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000484.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000485.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000486.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000487.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000488.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000489.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000490.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000491.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000492.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000493.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000494.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000495.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000496.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000497.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000498.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000499.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000500.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000501.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000502.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000503.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000504.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000505.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000506.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000507.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000508.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000509.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000510.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000511.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000512.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000513.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000514.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000515.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000516.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000517.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000518.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000519.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000520.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000521.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000522.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000523.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000525.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000526.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000527.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000528.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000529.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000530.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000531.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000532.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000533.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000534.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000535.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000536.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000537.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000538.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000539.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000540.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000541.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000542.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000544.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000546.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000547.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000548.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000549.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000550.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000551.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000552.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000553.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000554.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000555.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000556.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000557.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000558.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000559.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000561.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000562.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000563.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000564.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000565.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000566.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000567.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000568.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000569.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000570.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000571.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000572.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000573.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000574.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000575.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000576.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000578.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000579.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000580.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000581.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000582.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000583.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000585.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000586.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000587.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000588.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000589.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000590.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000591.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000592.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000593.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000594.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000595.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000596.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000597.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000598.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000599.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000600.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000602.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000603.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000605.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000606.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000607.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000609.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000610.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000611.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000612.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000614.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000615.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000616.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000617.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000618.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000619.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000620.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000622.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000623.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000624.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000625.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000627.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000628.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000629.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID14_000630.png
# ...
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID50_000861.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID50_000960.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID50_000984.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID50_001050.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID50_001080.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000000.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000030.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000060.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000090.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000120.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000150.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000180.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000210.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000270.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000330.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000480.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000510.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000540.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000570.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000600.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000660.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000720.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000780.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_000870.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001020.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001050.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001080.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001110.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001140.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001170.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001260.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001290.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001320.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001350.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001380.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001410.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001440.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001470.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001500.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001560.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001680.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001710.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001740.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001770.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001800.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001830.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001890.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_001920.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002010.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002040.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002070.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002100.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002130.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002190.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002280.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002310.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002340.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002400.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002430.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002460.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002490.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002580.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002820.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002850.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002910.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID51_002940.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000000.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000030.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000060.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000090.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000120.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000150.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000180.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000210.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000240.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000270.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000300.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000330.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000360.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000390.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000420.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000450.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000480.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000510.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000540.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000570.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000600.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000630.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000660.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000690.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000720.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000750.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000780.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000810.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000840.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000900.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000930.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000960.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_000990.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001020.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001050.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001080.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001110.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001140.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001170.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001200.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001230.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001260.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001290.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001320.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001350.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001410.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001440.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001470.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001620.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001740.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001770.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001830.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID65_001860.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000000.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000060.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000090.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000120.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000150.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000180.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000210.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000240.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000270.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000300.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000330.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000360.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000390.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000450.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000480.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000510.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000540.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000570.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000600.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000690.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000750.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000780.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000810.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000840.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000870.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000900.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000930.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000960.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_000990.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001020.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001050.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001080.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001110.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001140.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001170.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001200.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001230.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001260.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001290.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001380.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001500.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001530.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001560.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001590.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001620.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001650.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001740.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001770.png
# ../resnet_model/work_dirs/threetask_resnet_fpn_parallel_decoders/combined\t50_VID66_001800.png

# %% [markdown]
# ## Creating a movie

# %% [markdown]
# full - 0 to 0:20, 2:30 - 3:00,  4:30 - 4:50 , 5:39 - 6:20,
# sparse - 0:04-0:20, 0:35-0:45,  1:29-1:45

# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips, ColorClip

# Define the paths to your videos
full_video_path = '../../results/combined_videos/full.mp4'
sparse_video_path = '../../results/combined_videos/sparse.mp4'

# Load the video clips
full_video = VideoFileClip(full_video_path)
sparse_video = VideoFileClip(sparse_video_path)

# Define the segments to cut from each video
full_segments = [
    (0, 20),
    (150, 180),
    (270, 290),
    (339, 380)
]

sparse_segments = [
    (4, 20),
    (35, 45),
    (89, 105)
]

# Function to create a black screen clip for pause
def create_pause_clip(duration, size=(1920, 1080)):
    return ColorClip(size, color=(0, 0, 0), duration=duration)

# Create clips for each segment with pauses
clips = []

for start, end in full_segments:
    clip = full_video.subclip(start, end)
    clips.append(clip)
    clips.append(create_pause_clip(1, size=clip.size))  # Adding 1 second pause

for start, end in sparse_segments:
    clip = sparse_video.subclip(start, end)
    clips.append(clip)
    clips.append(create_pause_clip(1, size=clip.size))  # Adding 1 second pause

# Remove the last pause clip
if clips[-1].duration == 1:
    clips = clips[:-1]

# Concatenate the clips
final_video = concatenate_videoclips(clips, method="compose")

# Define the path for the output video
output_path = '../../results/combined_videos/combined.mp4'

# Write the result to a file
final_video.write_videofile(output_path, codec='libx264', audio_codec='aac')

print("Video has been successfully created and saved.")
# Out:
# [autoreload of decorator failed: Traceback (most recent call last):
#   File "c:\Users\tal22\Documents\repositories\cholec_instance_seg\.cholecinstanceseg\lib\site-packages\IPython\extensions\autoreload.py", line 273, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tal22\Documents\repositories\cholec_instance_seg\.cholecinstanceseg\lib\site-packages\IPython\extensions\autoreload.py", line 496, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\tal22\Documents\repositories\cholec_instance_seg\.cholecinstanceseg\lib\site-packages\IPython\extensions\autoreload.py", line 393, in update_generic
#     update(a, b)
#   File "c:\Users\tal22\Documents\repositories\cholec_instance_seg\.cholecinstanceseg\lib\site-packages\IPython\extensions\autoreload.py", line 305, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: ContextManager() requires a code object with 3 free vars, not 0
# ]
# The history saving thread hit an unexpected error (NameError("name 'fix' is not defined")).History will not be written to the database.
# Moviepy - Building video ../../results/combined_videos/combined.mp4.
# Moviepy - Writing video ../../results/combined_videos/combined.mp4
# Moviepy - Done !
# Moviepy - video ready ../../results/combined_videos/combined.mp4
# Video has been successfully created and saved.
