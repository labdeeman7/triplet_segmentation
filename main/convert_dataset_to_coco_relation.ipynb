# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')

# %% [markdown]
# ## Convert from my annotation to COCO

# %%
from utils.convert_to_coco.convert_dataset_to_coco_relations import annotations_to_coco_relations

# %%
split = 'val'
dataset_name = 'triplet_segmentation_dataset_v2'
dataset_path = f"../data/{dataset_name}/{split}" # enSure it contains img_dir and 
output_json_path = f"../data/{dataset_name}/coco_relation/{split}_coco_relation.json"
annotations_to_coco_relations(dataset_path, output_json_path, False)

# dataset_path = f"../data/triplet_segmentation_dataset_v2/{split}" # enSure it contains img_dir and 
# output_json_path = f"../data/triplet_segmentation_dataset_v2/coco_relation/{split}_coco_relation.json"
# annotations_to_coco_relations(dataset_path, output_json_path, False)
# Out:
# currently on 0, t50_VID110_000000.png, mask t50_VID110_000000.json
# currently on 1, t50_VID110_000030.png, mask t50_VID110_000030.json
# currently on 2, t50_VID110_000060.png, mask t50_VID110_000060.json
# currently on 3, t50_VID110_000090.png, mask t50_VID110_000090.json
# currently on 4, t50_VID110_000120.png, mask t50_VID110_000120.json
# currently on 5, t50_VID110_000150.png, mask t50_VID110_000150.json
# currently on 6, t50_VID110_000210.png, mask t50_VID110_000210.json
# currently on 7, t50_VID110_000240.png, mask t50_VID110_000240.json
# currently on 8, t50_VID110_000270.png, mask t50_VID110_000270.json
# currently on 9, t50_VID110_000300.png, mask t50_VID110_000300.json
# currently on 10, t50_VID110_000330.png, mask t50_VID110_000330.json
# currently on 11, t50_VID110_000360.png, mask t50_VID110_000360.json
# currently on 12, t50_VID110_000390.png, mask t50_VID110_000390.json
# currently on 13, t50_VID110_000420.png, mask t50_VID110_000420.json
# ...
