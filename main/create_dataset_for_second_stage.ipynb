# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

# %% [markdown]
# We need to take the json files, and make new ones.

# %%
from utils.convert_json_for_second_stage.convert_json_for_second_stage import convert_json_ann_to_second_stage_ann_for_a_dataset_split

# %%
# Load the JSON file
dataset_name = 'triplet_segmentation_v3_final'
split = 'mask2former_prediction_large' 
dataset_split_json_ann_dir = f'../data/{dataset_name}/{split}/ann_dir' 
dataset_split_img_dir = f'../data/{dataset_name}/{split}/img_dir' 
output_folder = f'../data/{dataset_name}/{split}/ann_second_stage'  # Directory to save the masks



# dataset_split_img_dir = f'../data/triplet_segmentation_dataset_v2_second_stage/test/img_dir' 
# dataset_split_json_ann_dir = f'../results/mas2former_on_cholecinstanceseg_pretrained/mask2former_test_triplet_segmentation_v2_results/mask2former_test_triplet_segmentation_v2_dataset'  
# output_folder = f'../results/mas2former_on_cholecinstanceseg_pretrained/mask2former_test_triplet_segmentation_v2_results/ann_second_stage'

# %%
convert_json_ann_to_second_stage_ann_for_a_dataset_split(dataset_split_json_ann_dir = dataset_split_json_ann_dir, 
                                                             dataset_split_img_dir = dataset_split_img_dir,
                                                             output_folder = output_folder)
# Out:
# Binary masks have been saved to ../data/triplet_segmentation_v3_final/mask2former_prediction_large/ann_second_stage.
# Binary masks have been saved to ../data/triplet_segmentation_v3_final/mask2former_prediction_large/ann_second_stage.
# Binary masks have been saved to ../data/triplet_segmentation_v3_final/mask2former_prediction_large/ann_second_stage.
# Binary masks have been saved to ../data/triplet_segmentation_v3_final/mask2former_prediction_large/ann_second_stage.
# Binary masks have been saved to ../data/triplet_segmentation_v3_final/mask2former_prediction_large/ann_second_stage.
# Binary masks have been saved to ../data/triplet_segmentation_v3_final/mask2former_prediction_large/ann_second_stage.
# Binary masks have been saved to ../data/triplet_segmentation_v3_final/mask2former_prediction_large/ann_second_stage.
# Binary masks have been saved to ../data/triplet_segmentation_v3_final/mask2former_prediction_large/ann_second_stage.
# ...
