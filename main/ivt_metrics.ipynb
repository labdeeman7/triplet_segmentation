# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

# %%
from ivtmetrics.ivtmetrics import Detection as ivtmetricsDetection
from utils.ivt_metrics_utils.ivt_metrics_utils import run_ivt_metric_object_for_folder

# %% [markdown]
# ## Get IVT metrics

# %%
ivt_metric_detection_object = ivtmetricsDetection()

# pred_ann_dir = f'../results/full_results_mask2former_multihead/mask2former_one_stage_multihead_full_best_coco_segm_mAP_iter_24500_results' 
# gt_ann_dir = f'../data/triplet_segmentation_dataset_v2/test/ann_dir'

# pred_ann_dir = f'../results/full_results_mask2former_multihead/mask2former_one_stage_multihead_full_iter_35000_results' 
# gt_ann_dir = f'../data/triplet_segmentation_dataset_v2/test/ann_dir'

# pred_ann_dir = f'../results/triplet_direct/mask2former_direct_triplet_prediction_best_coco_bbox_mAP_iter_60000_results' 
# gt_ann_dir = f'../data/triplet_segmentation_dataset_v2/test/ann_dir'

# pred_ann_dir = f'../resnet_model/results/combine_first_and_second_stage_results/mask2former_test_triplet_segmentation_v2_dataset_on_full' 
# gt_ann_dir = f'../data/triplet_segmentation_dataset_v2/test/ann_dir'

#fpn maskrcnn
# pred_ann_dir = f'../resnet_model/work_dirs/multitask_resnet_fpn/combine_first_and_second_stage_results' 
# gt_ann_dir = f'../data/triplet_segmentation_dataset_v2_second_stage/test/ann_dir'


# Mask2former standard
# pred_ann_dir = f'../resnet_model/work_dirs/multitask_resnet_standard/combine_first_and_second_stage_results' 
# gt_ann_dir = f'../data/triplet_segmentation_dataset_v2_second_stage/test/ann_dir'

# multitask_resnet_fpn_test_on_gt
pred_ann_dir = f'../resnet_model/work_dirs/multitask_resnet_fpn_test_on_gt/combine_first_and_second_stage_results' 
gt_ann_dir = f'../data/triplet_segmentation_dataset_v2_second_stage/test/ann_dir'


run_ivt_metric_object_for_folder(ivt_metric_object=ivt_metric_detection_object,
                                 pred_ann_dir=pred_ann_dir,
                                 gt_ann_dir=gt_ann_dir)
# Out:
# currently on 0, t50_VID14_000000.json
# pred, []
# gt, []
# original ground_truth []
# currently on 1, t50_VID14_000001.json
# pred, []
# gt, []
# original ground_truth []
# currently on 2, t50_VID14_000002.json
# pred, []
# gt, []
# original ground_truth []
# currently on 3, t50_VID14_000003.json
# pred, []
# gt, []
# original ground_truth []
# currently on 4, t50_VID14_000004.json
# pred, []
# gt, []
# original ground_truth []
# currently on 5, t50_VID14_000005.json
# pred, []
# gt, []
# original ground_truth []
# currently on 6, t50_VID14_000006.json
# pred, []
# gt, []
# original ground_truth []
# currently on 7, t50_VID14_000007.json
# pred, []
# gt, []
# original ground_truth []
# currently on 8, t50_VID14_000008.json
# pred, []
# gt, []
# original ground_truth []
# currently on 9, t50_VID14_000009.json
# pred, []
# gt, []
# original ground_truth []
# currently on 10, t50_VID14_000010.json
# pred, []
# gt, []
# original ground_truth []
# currently on 11, t50_VID14_000012.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.6791569086651054, 0.11666666666666667, 0.319672131147541, 0.5020833333333333], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.6791569086651054, 0.11666666666666667, 0.319672131147541, 0.5020833333333333], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.6791569086651054, 0.11666666666666667, 0.319672131147541, 0.5020833333333333], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.6791569086651054' '0.11666666666666667'
#   '0.319672131147541' '0.5020833333333333']]
#
#
#
#
#
# currently on 12, t50_VID14_000013.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.7072599531615925, 0.2708333333333333, 0.29156908665105385, 0.2125], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.7072599531615925, 0.2708333333333333, 0.29156908665105385, 0.2125], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.7072599531615925, 0.2708333333333333, 0.29156908665105385, 0.2125], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.7072599531615925' '0.2708333333333333'
#   '0.29156908665105385' '0.2125']]
#
#
#
#
#
# currently on 13, t50_VID14_000014.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.752927400468384, 0.0, 0.2189695550351288, 0.35208333333333336], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.752927400468384, 0.0, 0.2189695550351288, 0.35208333333333336], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.752927400468384, 0.0, 0.2189695550351288, 0.35208333333333336], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.752927400468384' '0.0' '0.2189695550351288'
#   '0.35208333333333336']]
#
#
#
#
#
# currently on 14, t50_VID14_000015.json
# pred, []
# gt, []
# original ground_truth []
# currently on 15, t50_VID14_000016.json
# pred, []
# gt, []
# original ground_truth []
# currently on 16, t50_VID14_000017.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.6088992974238876, 0.0, 0.12177985948477751, 0.08958333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.6088992974238876, 0.0, 0.12177985948477751, 0.08958333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.6088992974238876, 0.0, 0.12177985948477751, 0.08958333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.6088992974238876' '0.0' '0.12177985948477751'
#   '0.08958333333333333']]
#
#
#
#
#
# currently on 17, t50_VID14_000018.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.5562060889929742, 0.0, 0.24121779859484777, 0.16041666666666668], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.5562060889929742, 0.0, 0.24121779859484777, 0.16041666666666668], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.5562060889929742, 0.0, 0.24121779859484777, 0.16041666666666668], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.5562060889929742' '0.0' '0.24121779859484777'
#   '0.16041666666666668']]
#
#
#
#
#
# currently on 18, t50_VID14_000019.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.4964871194379391, 0.0, 0.13466042154566746, 0.11666666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.4964871194379391, 0.0, 0.13466042154566746, 0.11666666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.4964871194379391, 0.0, 0.13466042154566746, 0.11666666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.4964871194379391' '0.0' '0.13466042154566746'
#   '0.11666666666666667']]
#
#
#
#
#
# currently on 19, t50_VID14_000020.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.5257611241217799, 0.0, 0.47306791569086654, 0.36041666666666666], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.5257611241217799, 0.0, 0.47306791569086654, 0.36041666666666666], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.5257611241217799, 0.0, 0.47306791569086654, 0.36041666666666666], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.5257611241217799' '0.0' '0.47306791569086654'
#   '0.36041666666666666']]
#
#
#
#
#
# currently on 20, t50_VID14_000021.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.3407494145199063, 0.0, 0.10655737704918032, 0.09166666666666666], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.3407494145199063, 0.0, 0.10655737704918032, 0.09166666666666666], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.3407494145199063, 0.0, 0.10655737704918032, 0.09166666666666666], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.3407494145199063' '0.0' '0.10655737704918032'
#   '0.09166666666666666']]
#
#
#
#
#
# currently on 21, t50_VID14_000022.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.15807962529274006, 0.0, 0.08665105386416862, 0.07083333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.15807962529274006, 0.0, 0.08665105386416862, 0.07083333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.15807962529274006, 0.0, 0.08665105386416862, 0.07083333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.15807962529274006' '0.0' '0.08665105386416862'
#   '0.07083333333333333']]
#
#
#
#
#
# currently on 22, t50_VID14_000023.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.32084309133489464, 0.0, 0.25526932084309134, 0.2], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.32084309133489464, 0.0, 0.25526932084309134, 0.2], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.32084309133489464, 0.0, 0.25526932084309134, 0.2], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.32084309133489464' '0.0' '0.25526932084309134' '0.2']]
#
#
#
#
#
# currently on 23, t50_VID14_000024.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.3360655737704918, 0.0, 0.14168618266978922, 0.12916666666666668], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.3360655737704918, 0.0, 0.14168618266978922, 0.12916666666666668], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.3360655737704918, 0.0, 0.14168618266978922, 0.12916666666666668], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.3360655737704918' '0.0' '0.14168618266978922'
#   '0.12916666666666668']]
#
#
#
#
#
# currently on 24, t50_VID14_000025.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.34660421545667447, 0.0, 0.0468384074941452, 0.03125], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.34660421545667447, 0.0, 0.0468384074941452, 0.03125], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.34660421545667447, 0.0, 0.0468384074941452, 0.03125], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.34660421545667447' '0.0' '0.0468384074941452'
#   '0.03125']]
#
#
#
#
#
# currently on 25, t50_VID14_000026.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.36533957845433257, 0.0, 0.0936768149882904, 0.07083333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.36533957845433257, 0.0, 0.0936768149882904, 0.07083333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.36533957845433257, 0.0, 0.0936768149882904, 0.07083333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.36533957845433257' '0.0' '0.0936768149882904'
#   '0.07083333333333333']]
#
#
#
#
#
# currently on 26, t50_VID14_000119.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.47540983606557374, 0.0, 0.38992974238875877, 0.69375], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.48711943793911006, 0.0, 0.09953161592505855, 0.10416666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.47540983606557374, 0.0, 0.38992974238875877, 0.69375], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.48711943793911006, 0.0, 0.09953161592505855, 0.10416666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.47540983606557374, 0.0, 0.38992974238875877, 0.69375], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.48711943793911006, 0.0, 0.09953161592505855, 0.10416666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.48711943793911006' '0.0' '0.09953161592505855'
#   '0.10416666666666667']
#  ['61' '2' '1.0' '0.47540983606557374' '0.0' '0.38992974238875877'
#   '0.69375']]
#
#
#
#
#
# currently on 27, t50_VID14_000120.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.4449648711943794, 0.0, 0.43559718969555034, 0.6958333333333333], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.4847775175644028, 0.0, 0.09953161592505855, 0.10416666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.4449648711943794, 0.0, 0.43559718969555034, 0.6958333333333333], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.4847775175644028, 0.0, 0.09953161592505855, 0.10416666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.4449648711943794, 0.0, 0.43559718969555034, 0.6958333333333333], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.4847775175644028, 0.0, 0.09953161592505855, 0.10416666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.4847775175644028' '0.0' '0.09953161592505855'
#   '0.10416666666666667']
#  ['61' '2' '1.0' '0.4449648711943794' '0.0' '0.43559718969555034'
#   '0.6958333333333333']]
#
#
#
#
#
# currently on 28, t50_VID14_000121.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.48711943793911006, 0.0, 0.07728337236533958, 0.07916666666666666], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.5210772833723654, 0.0, 0.47306791569086654, 0.7416666666666667], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.48711943793911006, 0.0, 0.07728337236533958, 0.07916666666666666], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5210772833723654, 0.0, 0.47306791569086654, 0.7416666666666667], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.48711943793911006, 0.0, 0.07728337236533958, 0.07916666666666666], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5210772833723654, 0.0, 0.47306791569086654, 0.7416666666666667], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.5210772833723654' '0.0' '0.47306791569086654'
#   '0.7416666666666667']
#  ['17' '0' '1.0' '0.48711943793911006' '0.0' '0.07728337236533958'
#   '0.07916666666666666']]
#
#
#
#
#
# currently on 29, t50_VID14_000122.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.49765807962529274, 0.0, 0.0702576112412178, 0.075], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.6451990632318502, 0.0, 0.35362997658079626, 0.75], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.49765807962529274, 0.0, 0.0702576112412178, 0.075], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6451990632318502, 0.0, 0.35362997658079626, 0.75], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.49765807962529274, 0.0, 0.0702576112412178, 0.075], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6451990632318502, 0.0, 0.35362997658079626, 0.75], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6451990632318502' '0.0' '0.35362997658079626' '0.75']
#  ['17' '0' '1.0' '0.49765807962529274' '0.0' '0.0702576112412178' '0.075']]
#
#
#
#
#
# currently on 30, t50_VID14_000123.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.6744730679156908, 0.0, 0.32435597189695553, 0.66875], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.5, 0.0, 0.05503512880562061, 0.052083333333333336], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.6744730679156908, 0.0, 0.32435597189695553, 0.66875], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.5, 0.0, 0.05503512880562061, 0.052083333333333336], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.6744730679156908, 0.0, 0.32435597189695553, 0.66875], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.5, 0.0, 0.05503512880562061, 0.052083333333333336], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.5' '0.0' '0.05503512880562061' '0.052083333333333336']
#  ['61' '2' '1.0' '0.6744730679156908' '0.0' '0.32435597189695553'
#   '0.66875']]
#
#
#
#
#
# currently on 31, t50_VID14_000127.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5936768149882904, 0.0, 0.4063231850117096, 0.7666666666666667], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.5936768149882904, 0.0, 0.4063231850117096, 0.7666666666666667], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.5936768149882904, 0.0, 0.4063231850117096, 0.7666666666666667], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.5936768149882904' '0.0' '0.4063231850117096'
#   '0.7666666666666667']]
#
#
#
#
#
# currently on 32, t50_VID14_000128.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.0, 0.5666666666666667, 0.5480093676814989, 0.20625], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.6182669789227166, 0.0, 0.275175644028103, 0.4666666666666667], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.5666666666666667, 0.5480093676814989, 0.20625], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6182669789227166, 0.0, 0.275175644028103, 0.4666666666666667], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.5666666666666667, 0.5480093676814989, 0.20625], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6182669789227166, 0.0, 0.275175644028103, 0.4666666666666667], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6182669789227166' '0.0' '0.275175644028103'
#   '0.4666666666666667']
#  ['20' '0' '1.0' '0.0' '0.5666666666666667' '0.5480093676814989'
#   '0.20625']]
#
#
#
#
#
# currently on 33, t50_VID14_000129.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.0, 0.7979166666666667, 0.6428571428571429, 0.1875], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.544496487119438, 0.0, 0.3548009367681499, 0.6645833333333333], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.7979166666666667, 0.6428571428571429, 0.1875], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.544496487119438, 0.0, 0.3548009367681499, 0.6645833333333333], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.7979166666666667, 0.6428571428571429, 0.1875], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.544496487119438, 0.0, 0.3548009367681499, 0.6645833333333333], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.544496487119438' '0.0' '0.3548009367681499'
#   '0.6645833333333333']
#  ['20' '0' '1.0' '0.0' '0.7979166666666667' '0.6428571428571429' '0.1875']]
#
#
#
#
#
# currently on 34, t50_VID14_000130.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.0, 0.6229166666666667, 0.5491803278688525, 0.21041666666666667], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.5070257611241218, 0.0, 0.3044496487119438, 0.55625], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.6229166666666667, 0.5491803278688525, 0.21041666666666667], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5070257611241218, 0.0, 0.3044496487119438, 0.55625], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.6229166666666667, 0.5491803278688525, 0.21041666666666667], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5070257611241218, 0.0, 0.3044496487119438, 0.55625], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.5070257611241218' '0.0' '0.3044496487119438'
#   '0.55625']
#  ['20' '0' '1.0' '0.0' '0.6229166666666667' '0.5491803278688525'
#   '0.21041666666666667']]
#
#
#
#
#
# currently on 35, t50_VID14_000131.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.0, 0.60625, 0.6030444964871194, 0.23333333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.5117096018735363, 0.0, 0.28688524590163933, 0.5166666666666667], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.60625, 0.6030444964871194, 0.23333333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5117096018735363, 0.0, 0.28688524590163933, 0.5166666666666667], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.60625, 0.6030444964871194, 0.23333333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5117096018735363, 0.0, 0.28688524590163933, 0.5166666666666667], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.5117096018735363' '0.0' '0.28688524590163933'
#   '0.5166666666666667']
#  ['20' '0' '1.0' '0.0' '0.60625' '0.6030444964871194'
#   '0.23333333333333334']]
#
#
#
#
#
# currently on 36, t50_VID14_000132.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.0, 0.6875, 0.6229508196721312, 0.2520833333333333], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.531615925058548, 0.0, 0.32669789227166274, 0.6166666666666667], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.6875, 0.6229508196721312, 0.2520833333333333], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.531615925058548, 0.0, 0.32669789227166274, 0.6166666666666667], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.6875, 0.6229508196721312, 0.2520833333333333], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.531615925058548, 0.0, 0.32669789227166274, 0.6166666666666667], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.531615925058548' '0.0' '0.32669789227166274'
#   '0.6166666666666667']
#  ['20' '0' '1.0' '0.0' '0.6875' '0.6229508196721312' '0.2520833333333333']]
#
#
#
#
#
# currently on 37, t50_VID14_000133.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.7166666666666667, 0.629976580796253, 0.26458333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.5608899297423887, 0.0, 0.33138173302107726, 0.61875], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.7166666666666667, 0.629976580796253, 0.26458333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5608899297423887, 0.0, 0.33138173302107726, 0.61875], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.7166666666666667, 0.629976580796253, 0.26458333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5608899297423887, 0.0, 0.33138173302107726, 0.61875], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.5608899297423887' '0.0' '0.33138173302107726'
#   '0.61875']
#  ['20' '0' '1.0' '0.0' '0.7166666666666667' '0.629976580796253'
#   '0.26458333333333334']]
#
#
#
#
#
# currently on 38, t50_VID14_000134.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.7416666666666667, 0.6065573770491803, 0.24375], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.6194379391100703, 0.0, 0.3594847775175644, 0.6770833333333334], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.7416666666666667, 0.6065573770491803, 0.24375], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6194379391100703, 0.0, 0.3594847775175644, 0.6770833333333334], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.7416666666666667, 0.6065573770491803, 0.24375], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6194379391100703, 0.0, 0.3594847775175644, 0.6770833333333334], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6194379391100703' '0.0' '0.3594847775175644'
#   '0.6770833333333334']
#  ['20' '0' '1.0' '0.0' '0.7416666666666667' '0.6065573770491803'
#   '0.24375']]
#
#
#
#
#
# currently on 39, t50_VID14_000135.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.725, 0.5831381733021077, 0.25833333333333336], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.5140515222482436, 0.0, 0.29156908665105385, 0.5645833333333333], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.725, 0.5831381733021077, 0.25833333333333336], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5140515222482436, 0.0, 0.29156908665105385, 0.5645833333333333], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.725, 0.5831381733021077, 0.25833333333333336], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5140515222482436, 0.0, 0.29156908665105385, 0.5645833333333333], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.5140515222482436' '0.0' '0.29156908665105385'
#   '0.5645833333333333']
#  ['20' '0' '1.0' '0.0' '0.725' '0.5831381733021077' '0.25833333333333336']]
#
#
#
#
#
# currently on 40, t50_VID14_000136.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.73125, 0.5960187353629977, 0.25625], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.5023419203747073, 0.0, 0.3231850117096019, 0.5979166666666667], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.73125, 0.5960187353629977, 0.25625], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5023419203747073, 0.0, 0.3231850117096019, 0.5979166666666667], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.73125, 0.5960187353629977, 0.25625], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.5023419203747073, 0.0, 0.3231850117096019, 0.5979166666666667], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.5023419203747073' '0.0' '0.3231850117096019'
#   '0.5979166666666667']
#  ['20' '0' '1.0' '0.0' '0.73125' '0.5960187353629977' '0.25625']]
#
#
#
#
#
# currently on 41, t50_VID14_000137.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5526932084309133, 0.0, 0.2857142857142857, 0.575], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.0, 0.8333333333333334, 0.48360655737704916, 0.15625], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.5526932084309133, 0.0, 0.2857142857142857, 0.575], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.8333333333333334, 0.48360655737704916, 0.15625], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.5526932084309133, 0.0, 0.2857142857142857, 0.575], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.8333333333333334, 0.48360655737704916, 0.15625], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['20' '0' '1.0' '0.0' '0.8333333333333334' '0.48360655737704916'
#   '0.15625']
#  ['61' '2' '1.0' '0.5526932084309133' '0.0' '0.2857142857142857' '0.575']]
#
#
#
#
#
# currently on 42, t50_VID14_000138.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.6908665105386417, 0.0, 0.3091334894613583, 0.5833333333333334], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.6908665105386417, 0.0, 0.3091334894613583, 0.5833333333333334], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.6908665105386417, 0.0, 0.3091334894613583, 0.5833333333333334], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6908665105386417' '0.0' '0.3091334894613583'
#   '0.5833333333333334']]
#
#
#
#
#
# currently on 43, t50_VID14_000139.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.6194379391100703, 0.0, 0.36885245901639346, 0.68125], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.6194379391100703, 0.0, 0.36885245901639346, 0.68125], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.6194379391100703, 0.0, 0.36885245901639346, 0.68125], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6194379391100703' '0.0' '0.36885245901639346'
#   '0.68125']]
#
#
#
#
#
# currently on 44, t50_VID14_000140.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5245901639344263, 0.0, 0.35714285714285715, 0.6791666666666667], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.5245901639344263, 0.0, 0.35714285714285715, 0.6791666666666667], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.5245901639344263, 0.0, 0.35714285714285715, 0.6791666666666667], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.5245901639344263' '0.0' '0.35714285714285715'
#   '0.6791666666666667']]
#
#
#
#
#
# currently on 45, t50_VID14_000141.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.7915690866510539, 0.05416666666666667, 0.20843091334894615, 0.5395833333333333], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.7915690866510539, 0.05416666666666667, 0.20843091334894615, 0.5395833333333333], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.7915690866510539, 0.05416666666666667, 0.20843091334894615, 0.5395833333333333], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.7915690866510539' '0.05416666666666667'
#   '0.20843091334894615' '0.5395833333333333']]
#
#
#
#
#
# currently on 46, t50_VID14_000142.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.6358313817330211, 0.0020833333333333333, 0.34192037470725994, 0.6541666666666667], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.6358313817330211, 0.0020833333333333333, 0.34192037470725994, 0.6541666666666667], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.6358313817330211, 0.0020833333333333333, 0.34192037470725994, 0.6541666666666667], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6358313817330211' '0.0020833333333333333'
#   '0.34192037470725994' '0.6541666666666667']]
#
#
#
#
#
# currently on 47, t50_VID14_000143.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.6744730679156908, 0.00625, 0.3255269320843091, 0.7041666666666667], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.00351288056206089, 0.6979166666666666, 0.9882903981264637, 0.3020833333333333], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.6744730679156908, 0.00625, 0.3255269320843091, 0.7041666666666667], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.00351288056206089, 0.6979166666666666, 0.9882903981264637, 0.3020833333333333], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.6744730679156908, 0.00625, 0.3255269320843091, 0.7041666666666667], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.00351288056206089, 0.6979166666666666, 0.9882903981264637, 0.3020833333333333], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['20' '0' '1.0' '0.00351288056206089' '0.6979166666666666'
#   '0.9882903981264637' '0.3020833333333333']
#  ['61' '2' '1.0' '0.6744730679156908' '0.00625' '0.3255269320843091'
#   '0.7041666666666667']]
#
#
#
#
#
# currently on 48, t50_VID14_000144.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.7236533957845434, 0.020833333333333332, 0.27634660421545665, 0.70625], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.0, 0.8145833333333333, 0.6955503512880562, 0.175], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.7236533957845434, 0.020833333333333332, 0.27634660421545665, 0.70625], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.8145833333333333, 0.6955503512880562, 0.175], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.7236533957845434, 0.020833333333333332, 0.27634660421545665, 0.70625], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.8145833333333333, 0.6955503512880562, 0.175], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['20' '0' '1.0' '0.0' '0.8145833333333333' '0.6955503512880562' '0.175']
#  ['61' '2' '1.0' '0.7236533957845434' '0.020833333333333332'
#   '0.27634660421545665' '0.70625']]
#
#
#
#
#
# currently on 49, t50_VID14_000145.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.6583333333333333, 0.9988290398126464, 0.325], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.8138173302107728, 0.175, 0.18618266978922718, 0.5333333333333333], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.6583333333333333, 0.9988290398126464, 0.325], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.8138173302107728, 0.175, 0.18618266978922718, 0.5333333333333333], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.6583333333333333, 0.9988290398126464, 0.325], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.8138173302107728, 0.175, 0.18618266978922718, 0.5333333333333333], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.8138173302107728' '0.175' '0.18618266978922718'
#   '0.5333333333333333']
#  ['20' '0' '1.0' '0.0' '0.6583333333333333' '0.9988290398126464' '0.325']]
#
#
#
#
#
# currently on 50, t50_VID14_000146.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.7306791569086651, 0.016666666666666666, 0.2693208430913349, 0.74375], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.0, 0.7958333333333333, 0.775175644028103, 0.19583333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.7306791569086651, 0.016666666666666666, 0.2693208430913349, 0.74375], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.7958333333333333, 0.775175644028103, 0.19583333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.7306791569086651, 0.016666666666666666, 0.2693208430913349, 0.74375], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.7958333333333333, 0.775175644028103, 0.19583333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['20' '0' '1.0' '0.0' '0.7958333333333333' '0.775175644028103'
#   '0.19583333333333333']
#  ['61' '2' '1.0' '0.7306791569086651' '0.016666666666666666'
#   '0.2693208430913349' '0.74375']]
#
#
#
#
#
# currently on 51, t50_VID14_000147.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.6522248243559718, 0.0020833333333333333, 0.21194379391100704, 0.44375], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.0, 0.6958333333333333, 0.8957845433255269, 0.28958333333333336], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.6522248243559718, 0.0020833333333333333, 0.21194379391100704, 0.44375], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.6958333333333333, 0.8957845433255269, 0.28958333333333336], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.6522248243559718, 0.0020833333333333333, 0.21194379391100704, 0.44375], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.6958333333333333, 0.8957845433255269, 0.28958333333333336], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['20' '0' '1.0' '0.0' '0.6958333333333333' '0.8957845433255269'
#   '0.28958333333333336']
#  ['61' '2' '1.0' '0.6522248243559718' '0.0020833333333333333'
#   '0.21194379391100704' '0.44375']]
#
#
#
#
#
# currently on 52, t50_VID14_000148.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.44166666666666665, 0.6768149882903981, 0.21666666666666667], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.6615925058548009, 0.0, 0.18969555035128804, 0.36875], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.44166666666666665, 0.6768149882903981, 0.21666666666666667], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6615925058548009, 0.0, 0.18969555035128804, 0.36875], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.44166666666666665, 0.6768149882903981, 0.21666666666666667], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6615925058548009, 0.0, 0.18969555035128804, 0.36875], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6615925058548009' '0.0' '0.18969555035128804'
#   '0.36875']
#  ['20' '0' '1.0' '0.0' '0.44166666666666665' '0.6768149882903981'
#   '0.21666666666666667']]
#
#
#
#
#
# currently on 53, t50_VID14_000149.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5714285714285714, 0.0, 0.2646370023419204, 0.5666666666666667], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.0, 0.7416666666666667, 0.6615925058548009, 0.2375], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.5714285714285714, 0.0, 0.2646370023419204, 0.5666666666666667], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.7416666666666667, 0.6615925058548009, 0.2375], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.5714285714285714, 0.0, 0.2646370023419204, 0.5666666666666667], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '20', 'instrument': ['0', 1.0, 0.0, 0.7416666666666667, 0.6615925058548009, 0.2375], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['20' '0' '1.0' '0.0' '0.7416666666666667' '0.6615925058548009' '0.2375']
#  ['61' '2' '1.0' '0.5714285714285714' '0.0' '0.2646370023419204'
#   '0.5666666666666667']]
#
#
#
#
#
# currently on 54, t50_VID14_000150.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.6042154566744731, 0.0, 0.26229508196721313, 0.6375], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.6042154566744731, 0.0, 0.26229508196721313, 0.6375], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.6042154566744731, 0.0, 0.26229508196721313, 0.6375], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6042154566744731' '0.0' '0.26229508196721313'
#   '0.6375']]
#
#
#
#
#
# currently on 55, t50_VID14_000151.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.7704918032786885, 0.0, 0.18266978922716628, 0.3729166666666667], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '19', 'instrument': ['0', 1.0, 0.00234192037470726, 0.5625, 0.7482435597189696, 0.32708333333333334], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '61', 'instrument': ['2', 1.0, 0.7704918032786885, 0.0, 0.18266978922716628, 0.3729166666666667], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '18', 'instrument': ['0', 1.0, 0.00234192037470726, 0.5625, 0.7482435597189696, 0.32708333333333334], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '61', 'instrument': ['2', 1.0, 0.7704918032786885, 0.0, 0.18266978922716628, 0.3729166666666667], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '18', 'instrument': ['0', 1.0, 0.00234192037470726, 0.5625, 0.7482435597189696, 0.32708333333333334], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['18' '0' '1.0' '0.00234192037470726' '0.5625' '0.7482435597189696'
#   '0.32708333333333334']
#  ['61' '2' '1.0' '0.7704918032786885' '0.0' '0.18266978922716628'
#   '0.3729166666666667']]
#
#
#
#
#
# currently on 56, t50_VID14_000152.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.00117096018735363, 0.25, 0.8852459016393442, 0.28541666666666665], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.7939110070257611, 0.0, 0.1323185011709602, 0.26666666666666666], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '18', 'instrument': ['0', 1.0, 0.00117096018735363, 0.25, 0.8852459016393442, 0.28541666666666665], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.7939110070257611, 0.0, 0.1323185011709602, 0.26666666666666666], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '18', 'instrument': ['0', 1.0, 0.00117096018735363, 0.25, 0.8852459016393442, 0.28541666666666665], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.7939110070257611, 0.0, 0.1323185011709602, 0.26666666666666666], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.7939110070257611' '0.0' '0.1323185011709602'
#   '0.26666666666666666']
#  ['18' '0' '1.0' '0.00117096018735363' '0.25' '0.8852459016393442'
#   '0.28541666666666665']]
#
#
#
#
#
# currently on 57, t50_VID14_000153.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.4979166666666667, 0.870023419203747, 0.2625], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.7224824355971897, 0.0, 0.19437939110070257, 0.39791666666666664], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '18', 'instrument': ['0', 1.0, 0.0, 0.4979166666666667, 0.870023419203747, 0.2625], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.7224824355971897, 0.0, 0.19437939110070257, 0.39791666666666664], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '18', 'instrument': ['0', 1.0, 0.0, 0.4979166666666667, 0.870023419203747, 0.2625], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.7224824355971897, 0.0, 0.19437939110070257, 0.39791666666666664], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.7224824355971897' '0.0' '0.19437939110070257'
#   '0.39791666666666664']
#  ['18' '0' '1.0' '0.0' '0.4979166666666667' '0.870023419203747' '0.2625']]
#
#
#
#
#
# currently on 58, t50_VID14_000154.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.6416666666666667, 0.8056206088992974, 0.2708333333333333], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.6639344262295082, 0.0, 0.2716627634660422, 0.5770833333333333], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '18', 'instrument': ['0', 1.0, 0.0, 0.6416666666666667, 0.8056206088992974, 0.2708333333333333], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6639344262295082, 0.0, 0.2716627634660422, 0.5770833333333333], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '18', 'instrument': ['0', 1.0, 0.0, 0.6416666666666667, 0.8056206088992974, 0.2708333333333333], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6639344262295082, 0.0, 0.2716627634660422, 0.5770833333333333], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6639344262295082' '0.0' '0.2716627634660422'
#   '0.5770833333333333']
#  ['18' '0' '1.0' '0.0' '0.6416666666666667' '0.8056206088992974'
#   '0.2708333333333333']]
#
#
#
#
#
# currently on 59, t50_VID14_000155.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.6104166666666667, 0.7857142857142857, 0.26875], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.6463700234192038, 0.0, 0.24941451990632318, 0.5979166666666667], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '18', 'instrument': ['0', 1.0, 0.0, 0.6104166666666667, 0.7857142857142857, 0.26875], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6463700234192038, 0.0, 0.24941451990632318, 0.5979166666666667], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '18', 'instrument': ['0', 1.0, 0.0, 0.6104166666666667, 0.7857142857142857, 0.26875], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6463700234192038, 0.0, 0.24941451990632318, 0.5979166666666667], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6463700234192038' '0.0' '0.24941451990632318'
#   '0.5979166666666667']
#  ['18' '0' '1.0' '0.0' '0.6104166666666667' '0.7857142857142857'
#   '0.26875']]
#
#
#
#
#
# currently on 60, t50_VID14_000156.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.63125, 0.7810304449648712, 0.26875], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.6885245901639344, 0.0, 0.23653395784543327, 0.58125], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '18', 'instrument': ['0', 1.0, 0.0, 0.63125, 0.7810304449648712, 0.26875], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6885245901639344, 0.0, 0.23653395784543327, 0.58125], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '18', 'instrument': ['0', 1.0, 0.0, 0.63125, 0.7810304449648712, 0.26875], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.6885245901639344, 0.0, 0.23653395784543327, 0.58125], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.6885245901639344' '0.0' '0.23653395784543327'
#   '0.58125']
#  ['18' '0' '1.0' '0.0' '0.63125' '0.7810304449648712' '0.26875']]
#
#
#
#
#
# currently on 61, t50_VID14_000157.json
# pred, [{'triplet': '19', 'instrument': ['0', 1.0, 0.0, 0.7479166666666667, 0.797423887587822, 0.23333333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '60', 'instrument': ['2', 1.0, 0.7412177985948478, 0.0, 0.22950819672131148, 0.5645833333333333], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '18', 'instrument': ['0', 1.0, 0.0, 0.7479166666666667, 0.797423887587822, 0.23333333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.7412177985948478, 0.0, 0.22950819672131148, 0.5645833333333333], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '18', 'instrument': ['0', 1.0, 0.0, 0.7479166666666667, 0.797423887587822, 0.23333333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '61', 'instrument': ['2', 1.0, 0.7412177985948478, 0.0, 0.22950819672131148, 0.5645833333333333], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['61' '2' '1.0' '0.7412177985948478' '0.0' '0.22950819672131148'
#   '0.5645833333333333']
#  ['18' '0' '1.0' '0.0' '0.7479166666666667' '0.797423887587822'
#   '0.23333333333333334']]
#
#
#
#
#
# ...
#
#
#
#
#
# currently on 4131, t50_VID66_000930.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.3665105386416862, 0.0020833333333333333, 0.3840749414519906, 0.3], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.3665105386416862, 0.0020833333333333333, 0.3840749414519906, 0.3], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.3665105386416862, 0.0020833333333333333, 0.3840749414519906, 0.3], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.3665105386416862' '0.0020833333333333333'
#   '0.3840749414519906' '0.3']]
#
#
#
#
#
# currently on 4132, t50_VID66_000960.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5292740046838408, 0.09166666666666666, 0.4519906323185012, 0.7291666666666666], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5292740046838408, 0.09166666666666666, 0.4519906323185012, 0.7291666666666666], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.5292740046838408, 0.09166666666666666, 0.4519906323185012, 0.7291666666666666], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['60' '2' '1.0' '0.5292740046838408' '0.09166666666666666'
#   '0.4519906323185012' '0.7291666666666666']]
#
#
#
#
#
# currently on 4133, t50_VID66_000990.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.5105386416861827, 0.0, 0.33840749414519905, 0.22708333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '19', 'instrument': ['0', 1.0, 0.5105386416861827, 0.0, 0.33840749414519905, 0.22708333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '19', 'instrument': ['0', 1.0, 0.5105386416861827, 0.0, 0.33840749414519905, 0.22708333333333333], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['19' '0' '1.0' '0.5105386416861827' '0.0' '0.33840749414519905'
#   '0.22708333333333333']]
#
#
#
#
#
# currently on 4134, t50_VID66_001020.json
# pred, [{'triplet': '17', 'instrument': ['0', 1.0, 0.10772833723653395, 0.5145833333333333, 0.31381733021077285, 0.32708333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '29', 'instrument': ['1', 1.0, 0.1323185011709602, 0.28125, 0.8466042154566745, 0.59375], 'class_name': 'bipolar', 'instance_id': 1}]
# gt, [{'triplet': '17', 'instrument': ['0', 1.0, 0.10772833723653395, 0.5145833333333333, 0.31381733021077285, 0.32708333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '29', 'instrument': ['1', 1.0, 0.1323185011709602, 0.28125, 0.8466042154566745, 0.59375], 'class_name': 'bipolar', 'instance_id': 1}]
# original ground_truth [{'triplet': '17', 'instrument': ['0', 1.0, 0.10772833723653395, 0.5145833333333333, 0.31381733021077285, 0.32708333333333334], 'class_name': 'grasper', 'instance_id': 1}, {'triplet': '29', 'instrument': ['1', 1.0, 0.1323185011709602, 0.28125, 0.8466042154566745, 0.59375], 'class_name': 'bipolar', 'instance_id': 1}]
# after stacking detection_gt, [['29' '1' '1.0' '0.1323185011709602' '0.28125' '0.8466042154566745'
#   '0.59375']
#  ['17' '0' '1.0' '0.10772833723653395' '0.5145833333333333'
#   '0.31381733021077285' '0.32708333333333334']]
#
#
#
#
#
# currently on 4135, t50_VID66_001050.json
# pred, []
# gt, []
# original ground_truth []
# currently on 4136, t50_VID66_001080.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.3594847775175644, 0.10833333333333334, 0.5796252927400468, 0.8854166666666666], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.3594847775175644, 0.10833333333333334, 0.5796252927400468, 0.8854166666666666], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.3594847775175644, 0.10833333333333334, 0.5796252927400468, 0.8854166666666666], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['60' '2' '1.0' '0.3594847775175644' '0.10833333333333334'
#   '0.5796252927400468' '0.8854166666666666']]
#
#
#
#
#
# currently on 4137, t50_VID66_001110.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.4637002341920375, 0.28125, 0.4718969555035129, 0.7125], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.4637002341920375, 0.28125, 0.4718969555035129, 0.7125], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.4637002341920375, 0.28125, 0.4718969555035129, 0.7125], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['60' '2' '1.0' '0.4637002341920375' '0.28125' '0.4718969555035129'
#   '0.7125']]
#
#
#
#
#
# currently on 4138, t50_VID66_001140.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5737704918032787, 0.13333333333333333, 0.4133489461358314, 0.4395833333333333], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5737704918032787, 0.13333333333333333, 0.4133489461358314, 0.4395833333333333], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.5737704918032787, 0.13333333333333333, 0.4133489461358314, 0.4395833333333333], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['60' '2' '1.0' '0.5737704918032787' '0.13333333333333333'
#   '0.4133489461358314' '0.4395833333333333']]
#
#
#
#
#
# currently on 4139, t50_VID66_001170.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5140515222482436, 0.3229166666666667, 0.42505854800936765, 0.6666666666666666], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.09133489461358314, 0.32083333333333336, 0.15807962529274006, 0.1625], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5140515222482436, 0.3229166666666667, 0.42505854800936765, 0.6666666666666666], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.09133489461358314, 0.32083333333333336, 0.15807962529274006, 0.1625], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.5140515222482436, 0.3229166666666667, 0.42505854800936765, 0.6666666666666666], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.09133489461358314, 0.32083333333333336, 0.15807962529274006, 0.1625], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['17' '0' '1.0' '0.09133489461358314' '0.32083333333333336'
#   '0.15807962529274006' '0.1625']
#  ['60' '2' '1.0' '0.5140515222482436' '0.3229166666666667'
#   '0.42505854800936765' '0.6666666666666666']]
#
#
#
#
#
# currently on 4140, t50_VID66_001200.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.49882903981264637, 0.54375, 0.27400468384074944, 0.45], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.49882903981264637, 0.54375, 0.27400468384074944, 0.45], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.49882903981264637, 0.54375, 0.27400468384074944, 0.45], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['60' '2' '1.0' '0.49882903981264637' '0.54375' '0.27400468384074944'
#   '0.45']]
#
#
#
#
#
# currently on 4141, t50_VID66_001230.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5901639344262295, 0.18333333333333332, 0.3911007025761124, 0.55625], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5901639344262295, 0.18333333333333332, 0.3911007025761124, 0.55625], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.5901639344262295, 0.18333333333333332, 0.3911007025761124, 0.55625], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['60' '2' '1.0' '0.5901639344262295' '0.18333333333333332'
#   '0.3911007025761124' '0.55625']]
#
#
#
#
#
# currently on 4142, t50_VID66_001260.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.446135831381733, 0.0625, 0.5362997658079626, 0.8708333333333333], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.446135831381733, 0.0625, 0.5362997658079626, 0.8708333333333333], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.446135831381733, 0.0625, 0.5362997658079626, 0.8708333333333333], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['60' '2' '1.0' '0.446135831381733' '0.0625' '0.5362997658079626'
#   '0.8708333333333333']]
#
#
#
#
#
# currently on 4143, t50_VID66_001290.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5995316159250585, 0.18125, 0.382903981264637, 0.45416666666666666], 'class_name': 'hook', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5995316159250585, 0.18125, 0.382903981264637, 0.45416666666666666], 'class_name': 'hook', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.5995316159250585, 0.18125, 0.382903981264637, 0.45416666666666666], 'class_name': 'hook', 'instance_id': 1}]
# after stacking detection_gt, [['60' '2' '1.0' '0.5995316159250585' '0.18125' '0.382903981264637'
#   '0.45416666666666666']]
#
#
#
#
#
# currently on 4144, t50_VID66_001380.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.6487119437939111, 0.28958333333333336, 0.32201405152224827, 0.5625], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.22950819672131148, 0.0, 0.2459016393442623, 0.029166666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.6487119437939111, 0.28958333333333336, 0.32201405152224827, 0.5625], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '19', 'instrument': ['0', 1.0, 0.22950819672131148, 0.0, 0.2459016393442623, 0.029166666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.6487119437939111, 0.28958333333333336, 0.32201405152224827, 0.5625], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '19', 'instrument': ['0', 1.0, 0.22950819672131148, 0.0, 0.2459016393442623, 0.029166666666666667], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['19' '0' '1.0' '0.22950819672131148' '0.0' '0.2459016393442623'
#   '0.029166666666666667']
#  ['60' '2' '1.0' '0.6487119437939111' '0.28958333333333336'
#   '0.32201405152224827' '0.5625']]
#
#
#
#
#
# currently on 4145, t50_VID66_001500.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5515222482435597, 0.27291666666666664, 0.4016393442622951, 0.7208333333333333], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.629976580796253, 0.0, 0.12646370023419204, 0.0625], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.5515222482435597, 0.27291666666666664, 0.4016393442622951, 0.7208333333333333], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '19', 'instrument': ['0', 1.0, 0.629976580796253, 0.0, 0.12646370023419204, 0.0625], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.5515222482435597, 0.27291666666666664, 0.4016393442622951, 0.7208333333333333], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '19', 'instrument': ['0', 1.0, 0.629976580796253, 0.0, 0.12646370023419204, 0.0625], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['19' '0' '1.0' '0.629976580796253' '0.0' '0.12646370023419204' '0.0625']
#  ['60' '2' '1.0' '0.5515222482435597' '0.27291666666666664'
#   '0.4016393442622951' '0.7208333333333333']]
#
#
#
#
#
# currently on 4146, t50_VID66_001530.json
# pred, [{'triplet': '60', 'instrument': ['2', 1.0, 0.4098360655737705, 0.23333333333333334, 0.468384074941452, 0.7583333333333333], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '17', 'instrument': ['0', 1.0, 0.5889929742388759, 0.0, 0.08665105386416862, 0.04375], 'class_name': 'grasper', 'instance_id': 1}]
# gt, [{'triplet': '60', 'instrument': ['2', 1.0, 0.4098360655737705, 0.23333333333333334, 0.468384074941452, 0.7583333333333333], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '19', 'instrument': ['0', 1.0, 0.5889929742388759, 0.0, 0.08665105386416862, 0.04375], 'class_name': 'grasper', 'instance_id': 1}]
# original ground_truth [{'triplet': '60', 'instrument': ['2', 1.0, 0.4098360655737705, 0.23333333333333334, 0.468384074941452, 0.7583333333333333], 'class_name': 'hook', 'instance_id': 1}, {'triplet': '19', 'instrument': ['0', 1.0, 0.5889929742388759, 0.0, 0.08665105386416862, 0.04375], 'class_name': 'grasper', 'instance_id': 1}]
# after stacking detection_gt, [['19' '0' '1.0' '0.5889929742388759' '0.0' '0.08665105386416862'
#   '0.04375']
#  ['60' '2' '1.0' '0.4098360655737705' '0.23333333333333334'
#   '0.468384074941452' '0.7583333333333333']]
#
#
#
#
#
# currently on 4147, t50_VID66_001560.json
# pred, []
# gt, []
# original ground_truth []
# currently on 4148, t50_VID66_001590.json
# pred, [{'triplet': '99', 'instrument': ['5', 1.0, 0.6932084309133489, 0.24791666666666667, 0.28805620608899296, 0.3416666666666667], 'class_name': 'irrigator', 'instance_id': 1}, {'triplet': '28', 'instrument': ['1', 1.0, 0.6662763466042154, 0.0, 0.1451990632318501, 0.16666666666666666], 'class_name': 'bipolar', 'instance_id': 1}]
# gt, [{'triplet': '82', 'instrument': ['5', 1.0, 0.6932084309133489, 0.24791666666666667, 0.28805620608899296, 0.3416666666666667], 'class_name': 'irrigator', 'instance_id': 1}, {'triplet': '29', 'instrument': ['1', 1.0, 0.6662763466042154, 0.0, 0.1451990632318501, 0.16666666666666666], 'class_name': 'bipolar', 'instance_id': 1}]
# original ground_truth [{'triplet': '82', 'instrument': ['5', 1.0, 0.6932084309133489, 0.24791666666666667, 0.28805620608899296, 0.3416666666666667], 'class_name': 'irrigator', 'instance_id': 1}, {'triplet': '29', 'instrument': ['1', 1.0, 0.6662763466042154, 0.0, 0.1451990632318501, 0.16666666666666666], 'class_name': 'bipolar', 'instance_id': 1}]
# after stacking detection_gt, [['29' '1' '1.0' '0.6662763466042154' '0.0' '0.1451990632318501'
#   '0.16666666666666666']
#  ['82' '5' '1.0' '0.6932084309133489' '0.24791666666666667'
#   '0.28805620608899296' '0.3416666666666667']]
#
#
#
#
#
# currently on 4149, t50_VID66_001620.json
# pred, [{'triplet': '99', 'instrument': ['5', 1.0, 0.5562060889929742, 0.27291666666666664, 0.22131147540983606, 0.5541666666666667], 'class_name': 'irrigator', 'instance_id': 1}]
# gt, [{'triplet': '82', 'instrument': ['5', 1.0, 0.5562060889929742, 0.27291666666666664, 0.22131147540983606, 0.5541666666666667], 'class_name': 'irrigator', 'instance_id': 1}]
# original ground_truth [{'triplet': '82', 'instrument': ['5', 1.0, 0.5562060889929742, 0.27291666666666664, 0.22131147540983606, 0.5541666666666667], 'class_name': 'irrigator', 'instance_id': 1}]
# after stacking detection_gt, [['82' '5' '1.0' '0.5562060889929742' '0.27291666666666664'
#   '0.22131147540983606' '0.5541666666666667']]
#
#
#
#
#
# currently on 4150, t50_VID66_001650.json
# pred, []
# gt, []
# original ground_truth []
# currently on 4151, t50_VID66_001740.json
# pred, []
# gt, []
# original ground_truth []
# currently on 4152, t50_VID66_001770.json
# pred, [{'triplet': '29', 'instrument': ['1', 1.0, 0.4496487119437939, 0.5958333333333333, 0.5128805620608899, 0.4], 'class_name': 'bipolar', 'instance_id': 1}]
# gt, [{'triplet': '22', 'instrument': ['1', 1.0, 0.4496487119437939, 0.5958333333333333, 0.5128805620608899, 0.4], 'class_name': 'bipolar', 'instance_id': 1}]
# original ground_truth [{'triplet': '22', 'instrument': ['1', 1.0, 0.4496487119437939, 0.5958333333333333, 0.5128805620608899, 0.4], 'class_name': 'bipolar', 'instance_id': 1}]
# after stacking detection_gt, [['22' '1' '1.0' '0.4496487119437939' '0.5958333333333333'
#   '0.5128805620608899' '0.4']]
#
#
#
#
#
# currently on 4153, t50_VID66_001800.json
# pred, []
# gt, []
# original ground_truth []

# %%
results_i = ivt_metric_detection_object.compute_video_AP('i')
print(f'results_i, {results_i['mAP']*100}' )
results_v = ivt_metric_detection_object.compute_video_AP('v')
print(f'results_v, {results_v['mAP']*100}' )
results_t = ivt_metric_detection_object.compute_video_AP('t')
print(f'results_t, {results_t['mAP']*100}' )
results_iv = ivt_metric_detection_object.compute_video_AP('iv')
print(f'results_iv, {results_iv['mAP']*100}' )
results_it = ivt_metric_detection_object.compute_video_AP('it')
print(f'results_it, {results_it['mAP']*100}' )
results_ivt = ivt_metric_detection_object.compute_video_AP('ivt')
print(f'results_ivt, {results_ivt['mAP']*100}' )
# Out:
# results_i, 100.00000000000003
# results_v, 47.09279893804468
# results_t, 12.315529137195966
# results_iv, 22.279873095255137
# results_it, 8.92269758015689
# results_ivt, 7.404231874864983

# %%
results_ivt['mAP']*100
# Out:
# 3.9342657306110245
